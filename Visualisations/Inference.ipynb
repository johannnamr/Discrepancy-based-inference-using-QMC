# %% [markdown]
# <a href="https://colab.research.google.com/github/johannnamr/Discrepancy-based-inference-using-QMC/blob/main/Visualisations/Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inference results**

# %% [markdown]
# Mount drive:

# %%
# mount my drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Load libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.spatial.distance as distance

# %% [markdown]
# Set path to inference results:

# %%
path_inference = '/content/drive/My Drive/Colab Notebooks/Paper/Inference/'

# %% [markdown]
# ## Load data

# %% [markdown]
# Load inference results for bivariate beta distribution:

# %%
# sample complexity
bibeta_mmd2_n_int = np.load(path_inference+'bibeta_mmd2_n_vstat_kgaussian_int.npz')
bibeta_mmd2_n_noint = np.load(path_inference+'bibeta_mmd2_n_vstat_kgaussian_noint.npz')
bibeta_w_n_int = np.load(path_inference+'bibeta_w_n_euclidean_int.npz')
bibeta_w_n_noint = np.load(path_inference+'bibeta_w_n_euclidean_noint.npz')
bibeta_sw_n_int = np.load(path_inference+'bibeta_slicedw_n_nproj=100_euclidean_int.npz')
bibeta_sw_n_noint = np.load(path_inference+'bibeta_slicedw_n_nproj=100_euclidean_noint.npz')
bibeta_sink_n_int = np.load(path_inference+'bibeta_sink_n_sqeuclidean_int.npz')
bibeta_sink_n_noint = np.load(path_inference+'bibeta_sink_n_sqeuclidean_noint.npz')

# %%
# optimisation MMD^2
bibeta_mmd2_optim_mc_1 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_1.npz')
bibeta_mmd2_optim_mc_2 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_2.npz')
bibeta_mmd2_optim_mc_3 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_3.npz')
bibeta_mmd2_optim_mc_4 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_4.npz')
bibeta_mmd2_optim_mc_5 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_5.npz')
bibeta_mmd2_optim_mc_6 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_6.npz')
bibeta_mmd2_optim_mc_7 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_7.npz')
bibeta_mmd2_optim_mc_8 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_8.npz')
bibeta_mmd2_optim_mc_9 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_9.npz')
bibeta_mmd2_optim_mc_10 = np.load(path_inference+'bibeta_optim_mmd2_MC_n=512_0.npz')

# n
bibeta_mmd2_optim_rqmc_1 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_1.npz')
bibeta_mmd2_optim_rqmc_2 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_2.npz')
bibeta_mmd2_optim_rqmc_3 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_3.npz')
bibeta_mmd2_optim_rqmc_4 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_4.npz')
bibeta_mmd2_optim_rqmc_5 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_5.npz')
bibeta_mmd2_optim_rqmc_6 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_6.npz')
bibeta_mmd2_optim_rqmc_7 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_7.npz')
bibeta_mmd2_optim_rqmc_8 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_8.npz')
bibeta_mmd2_optim_rqmc_9 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_9.npz')
bibeta_mmd2_optim_rqmc_10 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=512_0.npz')

# n^{1/2}
bibeta_mmd2_optim_rqmc_n12_1 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_1.npz')
bibeta_mmd2_optim_rqmc_n12_2 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_2.npz')
bibeta_mmd2_optim_rqmc_n12_3 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_3.npz')
bibeta_mmd2_optim_rqmc_n12_4 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_4.npz')
bibeta_mmd2_optim_rqmc_n12_5 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_5.npz')
bibeta_mmd2_optim_rqmc_n12_6 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_6.npz')
bibeta_mmd2_optim_rqmc_n12_7 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_7.npz')
bibeta_mmd2_optim_rqmc_n12_8 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_8.npz')
bibeta_mmd2_optim_rqmc_n12_9 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_9.npz')
bibeta_mmd2_optim_rqmc_n12_10 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=23_0.npz')

# n^{2/3}
bibeta_mmd2_optim_rqmc_n23_1 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_1.npz')
bibeta_mmd2_optim_rqmc_n23_2 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_2.npz')
bibeta_mmd2_optim_rqmc_n23_3 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_3.npz')
bibeta_mmd2_optim_rqmc_n23_4 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_4.npz')
bibeta_mmd2_optim_rqmc_n23_5 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_5.npz')
bibeta_mmd2_optim_rqmc_n23_6 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_6.npz')
bibeta_mmd2_optim_rqmc_n23_7 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_7.npz')
bibeta_mmd2_optim_rqmc_n23_8 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_8.npz')
bibeta_mmd2_optim_rqmc_n23_9 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_9.npz')
bibeta_mmd2_optim_rqmc_n23_10 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=64_0.npz')

# n^{3/4}
bibeta_mmd2_optim_rqmc_n34_1 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_1.npz')
bibeta_mmd2_optim_rqmc_n34_2 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_2.npz')
bibeta_mmd2_optim_rqmc_n34_3 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_3.npz')
bibeta_mmd2_optim_rqmc_n34_4 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_4.npz')
bibeta_mmd2_optim_rqmc_n34_5 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_5.npz')
bibeta_mmd2_optim_rqmc_n34_6 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_6.npz')
bibeta_mmd2_optim_rqmc_n34_7 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_7.npz')
bibeta_mmd2_optim_rqmc_n34_8 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_8.npz')
bibeta_mmd2_optim_rqmc_n34_9 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_9.npz')
bibeta_mmd2_optim_rqmc_n34_10 = np.load(path_inference+'bibeta_optim_mmd2_RQMC_n=108_0.npz')

# %%
# optimisation Wasserstein distance
bibeta_w_optim_mc_1 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_1.npz')
bibeta_w_optim_mc_2 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_2.npz')
bibeta_w_optim_mc_3 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_3.npz')
bibeta_w_optim_mc_4 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_4.npz')
bibeta_w_optim_mc_5 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_5.npz')
bibeta_w_optim_mc_6 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_6.npz')
bibeta_w_optim_mc_7 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_7.npz')
bibeta_w_optim_mc_8 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_8.npz')
bibeta_w_optim_mc_9 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_9.npz')
bibeta_w_optim_mc_10 = np.load(path_inference+'bibeta_optim_wasserstein_MC_n=512_0.npz')

# n
bibeta_w_optim_rqmc_1 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_1.npz')
bibeta_w_optim_rqmc_2 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_2.npz')
bibeta_w_optim_rqmc_3 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_3.npz')
bibeta_w_optim_rqmc_4 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_4.npz')
bibeta_w_optim_rqmc_5 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_5.npz')
bibeta_w_optim_rqmc_6 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_6.npz')
bibeta_w_optim_rqmc_7 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_7.npz')
bibeta_w_optim_rqmc_8 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_8.npz')
bibeta_w_optim_rqmc_9 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_9.npz')
bibeta_w_optim_rqmc_10 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=512_0.npz')

# n^{1/2}
bibeta_w_optim_rqmc_n12_1 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_1.npz')
bibeta_w_optim_rqmc_n12_2 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_2.npz')
bibeta_w_optim_rqmc_n12_3 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_3.npz')
bibeta_w_optim_rqmc_n12_4 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_4.npz')
bibeta_w_optim_rqmc_n12_5 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_5.npz')
bibeta_w_optim_rqmc_n12_6 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_6.npz')
bibeta_w_optim_rqmc_n12_7 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_7.npz')
bibeta_w_optim_rqmc_n12_8 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_8.npz')
bibeta_w_optim_rqmc_n12_9 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_9.npz')
bibeta_w_optim_rqmc_n12_10 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=23_0.npz')

# n^{2/3}
bibeta_w_optim_rqmc_n23_1 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_1.npz')
bibeta_w_optim_rqmc_n23_2 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_2.npz')
bibeta_w_optim_rqmc_n23_3 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_3.npz')
bibeta_w_optim_rqmc_n23_4 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_4.npz')
bibeta_w_optim_rqmc_n23_5 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_5.npz')
bibeta_w_optim_rqmc_n23_6 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_6.npz')
bibeta_w_optim_rqmc_n23_7 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_7.npz')
bibeta_w_optim_rqmc_n23_8 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_8.npz')
bibeta_w_optim_rqmc_n23_9 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_9.npz')
bibeta_w_optim_rqmc_n23_10 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=64_0.npz')

# n^{3/4}
bibeta_w_optim_rqmc_n34_1 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_1.npz')
bibeta_w_optim_rqmc_n34_2 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_2.npz')
bibeta_w_optim_rqmc_n34_3 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_3.npz')
bibeta_w_optim_rqmc_n34_4 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_4.npz')
bibeta_w_optim_rqmc_n34_5 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_5.npz')
bibeta_w_optim_rqmc_n34_6 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_6.npz')
bibeta_w_optim_rqmc_n34_7 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_7.npz')
bibeta_w_optim_rqmc_n34_8 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_8.npz')
bibeta_w_optim_rqmc_n34_9 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_9.npz')
bibeta_w_optim_rqmc_n34_10 = np.load(path_inference+'bibeta_optim_wasserstein_RQMC_n=108_0.npz')

# %%
# optimisation sliced Wasserstein distance
bibeta_sw_optim_mc_1 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_1.npz')
bibeta_sw_optim_mc_2 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_2.npz')
bibeta_sw_optim_mc_3 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_3.npz')
bibeta_sw_optim_mc_4 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_4.npz')
bibeta_sw_optim_mc_5 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_5.npz')
bibeta_sw_optim_mc_6 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_6.npz')
bibeta_sw_optim_mc_7 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_7.npz')
bibeta_sw_optim_mc_8 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_8.npz')
bibeta_sw_optim_mc_9 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_9.npz')
bibeta_sw_optim_mc_10 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_MC_n=512_0.npz')

# n
bibeta_sw_optim_rqmc_1 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_1.npz')
bibeta_sw_optim_rqmc_2 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_2.npz')
bibeta_sw_optim_rqmc_3 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_3.npz')
bibeta_sw_optim_rqmc_4 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_4.npz')
bibeta_sw_optim_rqmc_5 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_5.npz')
bibeta_sw_optim_rqmc_6 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_6.npz')
bibeta_sw_optim_rqmc_7 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_7.npz')
bibeta_sw_optim_rqmc_8 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_8.npz')
bibeta_sw_optim_rqmc_9 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_9.npz')
bibeta_sw_optim_rqmc_10 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=512_0.npz')

# n^{1/2}
bibeta_sw_optim_rqmc_n12_1 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_1.npz')
bibeta_sw_optim_rqmc_n12_2 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_2.npz')
bibeta_sw_optim_rqmc_n12_3 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_3.npz')
bibeta_sw_optim_rqmc_n12_4 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_4.npz')
bibeta_sw_optim_rqmc_n12_5 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_5.npz')
bibeta_sw_optim_rqmc_n12_6 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_6.npz')
bibeta_sw_optim_rqmc_n12_7 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_7.npz')
bibeta_sw_optim_rqmc_n12_8 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_8.npz')
bibeta_sw_optim_rqmc_n12_9 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_9.npz')
bibeta_sw_optim_rqmc_n12_10 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=23_0.npz')

# n^{2/3}
bibeta_sw_optim_rqmc_n23_1 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_1.npz')
bibeta_sw_optim_rqmc_n23_2 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_2.npz')
bibeta_sw_optim_rqmc_n23_3 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_3.npz')
bibeta_sw_optim_rqmc_n23_4 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_4.npz')
bibeta_sw_optim_rqmc_n23_5 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_5.npz')
bibeta_sw_optim_rqmc_n23_6 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_6.npz')
bibeta_sw_optim_rqmc_n23_7 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_7.npz')
bibeta_sw_optim_rqmc_n23_8 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_8.npz')
bibeta_sw_optim_rqmc_n23_9 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_9.npz')
bibeta_sw_optim_rqmc_n23_10 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=64_0.npz')

# n^{3/4}
bibeta_sw_optim_rqmc_n34_1 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_1.npz')
bibeta_sw_optim_rqmc_n34_2 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_2.npz')
bibeta_sw_optim_rqmc_n34_3 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_3.npz')
bibeta_sw_optim_rqmc_n34_4 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_4.npz')
bibeta_sw_optim_rqmc_n34_5 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_5.npz')
bibeta_sw_optim_rqmc_n34_6 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_6.npz')
bibeta_sw_optim_rqmc_n34_7 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_7.npz')
bibeta_sw_optim_rqmc_n34_8 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_8.npz')
bibeta_sw_optim_rqmc_n34_9 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_9.npz')
bibeta_sw_optim_rqmc_n34_10 = np.load(path_inference+'bibeta_optim_sliced_wasserstein_RQMC_n=108_0.npz')

# %%
# optimisation Sinkhorn divergence
bibeta_sink_optim_mc_1 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_1.npz')
bibeta_sink_optim_mc_2 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_2.npz')
bibeta_sink_optim_mc_3 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_3.npz')
bibeta_sink_optim_mc_4 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_4.npz')
bibeta_sink_optim_mc_5 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_5.npz')
bibeta_sink_optim_mc_6 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_6.npz')
bibeta_sink_optim_mc_7 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_7.npz')
bibeta_sink_optim_mc_8 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_8.npz')
bibeta_sink_optim_mc_9 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_9.npz')
bibeta_sink_optim_mc_10 = np.load(path_inference+'bibeta_optim_sinkhorn_MC_n=512_0.npz')

# n
bibeta_sink_optim_rqmc_1 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_1.npz')
bibeta_sink_optim_rqmc_2 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_2.npz')
bibeta_sink_optim_rqmc_3 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_3.npz')
bibeta_sink_optim_rqmc_4 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_4.npz')
bibeta_sink_optim_rqmc_5 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_5.npz')
bibeta_sink_optim_rqmc_6 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_6.npz')
bibeta_sink_optim_rqmc_7 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_7.npz')
bibeta_sink_optim_rqmc_8 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_8.npz')
bibeta_sink_optim_rqmc_9 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_9.npz')
bibeta_sink_optim_rqmc_10 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=512_0.npz')

# n^{1/2}
bibeta_sink_optim_rqmc_n12_1 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_1.npz')
bibeta_sink_optim_rqmc_n12_2 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_2.npz')
bibeta_sink_optim_rqmc_n12_3 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_3.npz')
bibeta_sink_optim_rqmc_n12_4 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_4.npz')
bibeta_sink_optim_rqmc_n12_5 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_5.npz')
bibeta_sink_optim_rqmc_n12_6 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_6.npz')
bibeta_sink_optim_rqmc_n12_7 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_7.npz')
bibeta_sink_optim_rqmc_n12_8 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_8.npz')
bibeta_sink_optim_rqmc_n12_9 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_9.npz')
bibeta_sink_optim_rqmc_n12_10 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=23_0.npz')

# n^{2/3}
bibeta_sink_optim_rqmc_n23_1 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_1.npz')
bibeta_sink_optim_rqmc_n23_2 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_2.npz')
bibeta_sink_optim_rqmc_n23_3 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_3.npz')
bibeta_sink_optim_rqmc_n23_4 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_4.npz')
bibeta_sink_optim_rqmc_n23_5 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_5.npz')
bibeta_sink_optim_rqmc_n23_6 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_6.npz')
bibeta_sink_optim_rqmc_n23_7 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_7.npz')
bibeta_sink_optim_rqmc_n23_8 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_8.npz')
bibeta_sink_optim_rqmc_n23_9 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_9.npz')
bibeta_sink_optim_rqmc_n23_10 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=64_0.npz')

# n^{3/4}
bibeta_sink_optim_rqmc_n34_1 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_1.npz')
bibeta_sink_optim_rqmc_n34_2 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_2.npz')
bibeta_sink_optim_rqmc_n34_3 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_3.npz')
bibeta_sink_optim_rqmc_n34_4 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_4.npz')
bibeta_sink_optim_rqmc_n34_5 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_5.npz')
bibeta_sink_optim_rqmc_n34_6 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_6.npz')
bibeta_sink_optim_rqmc_n34_7 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_7.npz')
bibeta_sink_optim_rqmc_n34_8 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_8.npz')
bibeta_sink_optim_rqmc_n34_9 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_9.npz')
bibeta_sink_optim_rqmc_n34_10 = np.load(path_inference+'bibeta_optim_sinkhorn_RQMC_n=108_0.npz')

# %% [markdown]
# Elements in each dataset:
#
# time\
# loss\
# theta\
# optloss

# %% [markdown]
# Load inference results for the multivariate g-and-k distribution:

# %%
# sample complexity MMD^2 (l=1.5d^{1/2})
mvgandk_mmd2_d = np.load(path_inference+'mvgandk_mmd2_d_n=8192_vstat_kgaussian.npz')
mvgandk_mmd2_n_d1 = np.load(path_inference+'mvgandk_mmd2_n_d=1_vstat_kgaussian.npz')
mvgandk_mmd2_n_d5 = np.load(path_inference+'mvgandk_mmd2_n_d=5_vstat_kgaussian.npz')
mvgandk_mmd2_n_d10 = np.load(path_inference+'mvgandk_mmd2_n_d=10_vstat_kgaussian.npz')
mvgandk_mmd2_n_d25 = np.load(path_inference+'mvgandk_mmd2_n_d=25_vstat_kgaussian.npz')
mvgandk_mmd2_n_d50 = np.load(path_inference+'mvgandk_mmd2_n_d=50_vstat_kgaussian.npz')

# %%
# sample complexity sliced Wasserstein distance
mvgandk_sw_d = np.load(path_inference+'mvgandk_slicedw_d_n=8192_nproj=100_euclidean.npz')
mvgandk_sw_n_d1 = np.load(path_inference+'mvgandk_slicedw_n_d=1_nproj=100_euclidean.npz')
mvgandk_sw_n_d5 = np.load(path_inference+'mvgandk_slicedw_n_d=5_nproj=100_euclidean.npz')
mvgandk_sw_n_d10 = np.load(path_inference+'mvgandk_slicedw_n_d=10_nproj=100_euclidean.npz')
mvgandk_sw_n_d25 = np.load(path_inference+'mvgandk_slicedw_n_d=25_nproj=100_euclidean.npz')
mvgandk_sw_n_d50 = np.load(path_inference+'mvgandk_slicedw_n_d=50_nproj=100_euclidean.npz')

# %%
# sample complexity Sinkhorn (\lambda=5d)
mvgandk_sink_d = np.load(path_inference+'mvgandk_sink_d_n=8192_sqeuclidean.npz') # n=2^{12}
mvgandk_sink_n_d1 = np.load(path_inference+'mvgandk_sink_n_d=1_sqeuclidean.npz',allow_pickle=True) # up to 2^{13}
mvgandk_sink_n_d5 = np.load(path_inference+'mvgandk_sink_n_d=5_sqeuclidean.npz') # up to 2^{13}
mvgandk_sink_n_d10 = np.load(path_inference+'mvgandk_sink_n_d=10_sqeuclidean.npz')
mvgandk_sink_n_d25 = np.load(path_inference+'mvgandk_sink_n_d=25_sqeuclidean.npz')
mvgandk_sink_n_d50 = np.load(path_inference+'mvgandk_sink_n_d=50_sqeuclidean.npz')

# %%
# univariate
gank_mmd2_optim_kgaussian = np.load(path_inference+'gandk_mmd2_optim_d=1_vstat_kgaussian_m=16384_eta=02.npz')

# %%
# multivariate
mvgandk_mmd2_optim_d1_mc = np.load(path_inference+'mvgandk_mmd2_optim_d=1_vstat_MC_eta=0.2.npz')
mvgandk_mmd2_optim_d1_rqmc = np.load(path_inference+'mvgandk_mmd2_optim_d=1_vstat_RQMC_eta=0.2.npz')
mvgandk_mmd2_optim_d2_mc = np.load(path_inference+'mvgandk_mmd2_optim_d=2_vstat_MC_eta=0.2.npz')
mvgandk_mmd2_optim_d2_rqmc = np.load(path_inference+'mvgandk_mmd2_optim_d=2_vstat_RQMC_eta=0.2.npz')
mvgandk_mmd2_optim_d5_mc = np.load(path_inference+'mvgandk_mmd2_optim_d=5_vstat_MC_eta=0.2.npz')
mvgandk_mmd2_optim_d5_rqmc = np.load(path_inference+'mvgandk_mmd2_optim_d=5_vstat_RQMC_eta=0.2.npz')
mvgandk_mmd2_optim_d10_mc = np.load(path_inference+'mvgandk_mmd2_optim_d=10_vstat_MC_eta=0.2.npz')
mvgandk_mmd2_optim_d10_rqmc = np.load(path_inference+'mvgandk_mmd2_optim_d=10_vstat_RQMC_eta=0.2.npz')
mvgandk_mmd2_optim_d15_mc = np.load(path_inference+'mvgandk_mmd2_optim_d=15_vstat_MC_eta=0.2.npz')
mvgandk_mmd2_optim_d15_rqmc = np.load(path_inference+'mvgandk_mmd2_optim_d=15_vstat_RQMC_eta=0.2.npz')
mvgandk_mmd2_optim_d20_mc = np.load(path_inference+'mvgandk_mmd2_optim_d=20_vstat_MC_eta=0.2.npz')
mvgandk_mmd2_optim_d20_rqmc = np.load(path_inference+'mvgandk_mmd2_optim_d=20_vstat_RQMC_eta=0.2.npz')
mvgandk_mmd2_optim_d25_mc = np.load(path_inference+'mvgandk_mmd2_optim_d=25_vstat_MC_eta=0.2.npz')
mvgandk_mmd2_optim_d25_rqmc = np.load(path_inference+'mvgandk_mmd2_optim_d=25_vstat_RQMC_eta=0.2.npz')

# %% [markdown]
# Elements in each dataset:
#
# loss\
# theta

# %% [markdown]
# ## Bivariate Beta distribution

# %% [markdown]
# Sample complexity results for the bivariate beta distribution with varying $n$ ($l=1.5d^{1/2}$, $e=5d$):

# %%
n = [ 2**j for j in range(3,15) ]

# %%
SMALL_SIZE = 26
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(18,8),sharey='row')
cmap = plt.get_cmap("tab10")

# \theta=(1,1,1,1,1)
ax1.plot(n, bibeta_mmd2_n_int['mmd_rqmc'], linewidth=2, color=cmap(0), label=r'$D=\widehat{MMD}^2_V$')
ax1.plot(n, bibeta_mmd2_n_int['mmd_mc'],'--', linewidth=2, color=cmap(0))
ax1.plot(n, bibeta_w_n_int['w_rqmc'], linewidth=2, color=cmap(1), label=r'$D=W_{c,p}$')
ax1.plot(n, bibeta_w_n_int['w_mc'],'--', linewidth=2, color=cmap(1))
ax1.plot(n, bibeta_sw_n_int['w_rqmc'], linewidth=2, color=cmap(2), label=r'$D=SW_{c,p}$')
ax1.plot(n, bibeta_sw_n_int['w_mc'],'--', linewidth=2, color=cmap(2))
ax1.plot(n, bibeta_sink_n_int['sink_rqmc'], linewidth=2, color=cmap(3), label=r'$D=S_{c,p,\lambda}$')
ax1.plot(n, bibeta_sink_n_int['sink_mc'],'--', linewidth=2, color=cmap(3))
ax1.errorbar(n, bibeta_mmd2_n_int['mmd_mc'], yerr=[bibeta_mmd2_n_int['mmd_mc']-bibeta_mmd2_n_int['mmd_min_mc'],bibeta_mmd2_n_int['mmd_max_mc']-bibeta_mmd2_n_int['mmd_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n, bibeta_mmd2_n_int['mmd_rqmc'], yerr=[bibeta_mmd2_n_int['mmd_rqmc']-bibeta_mmd2_n_int['mmd_min_rqmc'],bibeta_mmd2_n_int['mmd_max_rqmc']-bibeta_mmd2_n_int['mmd_rqmc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n, bibeta_w_n_int['w_mc'], yerr=[bibeta_w_n_int['w_mc']-bibeta_w_n_int['w_min_mc'],bibeta_w_n_int['w_max_mc']-bibeta_w_n_int['w_mc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n, bibeta_w_n_int['w_rqmc'], yerr=[bibeta_w_n_int['w_rqmc']-bibeta_w_n_int['w_min_rqmc'],bibeta_w_n_int['w_max_rqmc']-bibeta_w_n_int['w_rqmc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n, bibeta_sw_n_int['w_rqmc'], yerr=[bibeta_sw_n_int['w_rqmc']-bibeta_sw_n_int['w_min_rqmc'],bibeta_sw_n_int['w_max_rqmc']-bibeta_sw_n_int['w_rqmc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n, bibeta_sw_n_int['w_mc'], yerr=[bibeta_sw_n_int['w_mc']-bibeta_sw_n_int['w_min_mc'],bibeta_sw_n_int['w_max_mc']-bibeta_sw_n_int['w_mc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n, bibeta_sink_n_int['sink_rqmc'], yerr=[bibeta_sink_n_int['sink_rqmc']-bibeta_sink_n_int['sink_min_rqmc'],bibeta_sink_n_int['sink_max_rqmc']-bibeta_sink_n_int['sink_rqmc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n, bibeta_sink_n_int['sink_mc'], yerr=[bibeta_sink_n_int['sink_mc']-bibeta_sink_n_int['sink_min_mc'],bibeta_sink_n_int['sink_max_mc']-bibeta_sink_n_int['sink_mc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.set_xscale('log', basex=2)
ax1.set_yscale('log', basey=10)
ax1.set_xlabel('n=m')
ax1.set_ylabel(r'$|D(P^n,Q^m)|$')
ax1.set_title(r'$\theta=$'+'(1, 1, 1, 1, 1)')

# \theta=(1.5,1.5,1.5,1.5,1.5)
ax2.plot(n, bibeta_mmd2_n_noint['mmd_rqmc'], linewidth=2, color=cmap(0), label=r'$D=\widehat{MMD}^2_V$')
ax2.plot(n, bibeta_mmd2_n_noint['mmd_mc'],'--', linewidth=2, color=cmap(0))
ax2.plot(n, bibeta_w_n_noint['w_rqmc'], linewidth=2, color=cmap(1), label=r'$D=W_{c,p}$')
ax2.plot(n, bibeta_w_n_noint['w_mc'],'--', linewidth=2, color=cmap(1))
ax2.plot(n, bibeta_sw_n_noint['w_rqmc'], linewidth=2, color=cmap(2), label=r'$D=SW_{c,p}$')
ax2.plot(n, bibeta_sw_n_noint['w_mc'],'--', linewidth=2, color=cmap(2))
ax2.plot(n, bibeta_sink_n_noint['sink_rqmc'], linewidth=2, color=cmap(3), label=r'$D=S_{c,p,\lambda}$')
ax2.plot(n, bibeta_sink_n_noint['sink_mc'],'--', linewidth=2, color=cmap(3))
ax2.errorbar(n, bibeta_mmd2_n_noint['mmd_mc'], yerr=[bibeta_mmd2_n_noint['mmd_mc']-bibeta_mmd2_n_noint['mmd_min_mc'],bibeta_mmd2_n_noint['mmd_max_mc']-bibeta_mmd2_n_noint['mmd_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2.errorbar(n, bibeta_mmd2_n_noint['mmd_rqmc'], yerr=[bibeta_mmd2_n_noint['mmd_rqmc']-bibeta_mmd2_n_noint['mmd_min_rqmc'],bibeta_mmd2_n_noint['mmd_max_rqmc']-bibeta_mmd2_n_noint['mmd_rqmc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2.errorbar(n, bibeta_w_n_noint['w_mc'], yerr=[bibeta_w_n_noint['w_mc']-bibeta_w_n_noint['w_min_mc'],bibeta_w_n_noint['w_max_mc']-bibeta_w_n_noint['w_mc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax2.errorbar(n, bibeta_w_n_noint['w_rqmc'], yerr=[bibeta_w_n_noint['w_rqmc']-bibeta_w_n_noint['w_min_rqmc'],bibeta_w_n_noint['w_max_rqmc']-bibeta_w_n_noint['w_rqmc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax2.errorbar(n, bibeta_sw_n_noint['w_rqmc'], yerr=[bibeta_sw_n_noint['w_rqmc']-bibeta_sw_n_noint['w_min_rqmc'],bibeta_sw_n_noint['w_max_rqmc']-bibeta_sw_n_noint['w_rqmc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2.errorbar(n, bibeta_sw_n_noint['w_mc'], yerr=[bibeta_sw_n_noint['w_mc']-bibeta_sw_n_noint['w_min_mc'],bibeta_sw_n_noint['w_max_mc']-bibeta_sw_n_noint['w_mc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2.errorbar(n, bibeta_sink_n_noint['sink_rqmc'], yerr=[bibeta_sink_n_noint['sink_rqmc']-bibeta_sink_n_noint['sink_min_rqmc'],bibeta_sink_n_noint['sink_max_rqmc']-bibeta_sink_n_noint['sink_rqmc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax2.errorbar(n, bibeta_sink_n_noint['sink_mc'], yerr=[bibeta_sink_n_noint['sink_mc']-bibeta_sink_n_noint['sink_min_mc'],bibeta_sink_n_noint['sink_max_mc']-bibeta_sink_n_noint['sink_mc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax2.set_xscale('log', basex=2)
ax2.set_yscale('log', basey=10)
ax2.set_xlabel('n=m')
ax2.set_title(r'$\theta=$'+'(1.5, 1.5, 1.5, 1.5, 1.5)')
ax2.legend(loc= 'lower left', ncol=2,handlelength=1.5,labelspacing=0.3,handletextpad=0.3,columnspacing=1)

plt.subplots_adjust(wspace=0.05, hspace=0.05)

plt.savefig('bibeta_sample_complexity.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %% [markdown]
# Optimisation results for bivariate beta distribution:

# %% [markdown]
# Optimisation loss after 3000 iterations with $m=2^{16}$, $m\text{_}sub=2^{10}$ and $n=2^9$, $n=(2^9)^{1/2}$, $n=(2^9)^{2/3}$ or $n=(2^9)^{3/4}$ for $\widehat{\text{MMD}}^2$ ($l=1.5d^{1/2}$), 1-Wasserstein distance, 1-sliced Wasserstein distance (100 projections), and Sinkhorn divergence ($\lambda=5d$) using RQMC:

# %%
SMALL_SIZE = 26
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
# mmd^2
loss_mmd2_mc = (bibeta_mmd2_optim_mc_1['loss'],bibeta_mmd2_optim_mc_2['loss'],bibeta_mmd2_optim_mc_3['loss'],bibeta_mmd2_optim_mc_4['loss'],bibeta_mmd2_optim_mc_5['loss'],bibeta_mmd2_optim_mc_6['loss'],bibeta_mmd2_optim_mc_7['loss'],bibeta_mmd2_optim_mc_8['loss'],bibeta_mmd2_optim_mc_9['loss'],bibeta_mmd2_optim_mc_10['loss'])
loss_mmd2_rqmc = (bibeta_mmd2_optim_rqmc_1['loss'],bibeta_mmd2_optim_rqmc_2['loss'],bibeta_mmd2_optim_rqmc_3['loss'],bibeta_mmd2_optim_rqmc_4['loss'],bibeta_mmd2_optim_rqmc_5['loss'],bibeta_mmd2_optim_rqmc_6['loss'],bibeta_mmd2_optim_rqmc_7['loss'],bibeta_mmd2_optim_rqmc_8['loss'],bibeta_mmd2_optim_rqmc_9['loss'],bibeta_mmd2_optim_rqmc_10['loss'])

# w
loss_w_mc = (bibeta_w_optim_mc_1['loss'],bibeta_w_optim_mc_2['loss'],bibeta_w_optim_mc_3['loss'],bibeta_w_optim_mc_4['loss'],bibeta_w_optim_mc_5['loss'],bibeta_w_optim_mc_6['loss'],bibeta_w_optim_mc_7['loss'],bibeta_w_optim_mc_8['loss'],bibeta_w_optim_mc_9['loss'],bibeta_w_optim_mc_10['loss'])
loss_w_rqmc = (bibeta_w_optim_rqmc_1['loss'],bibeta_w_optim_rqmc_2['loss'],bibeta_w_optim_rqmc_3['loss'],bibeta_w_optim_rqmc_4['loss'],bibeta_w_optim_rqmc_5['loss'],bibeta_w_optim_rqmc_6['loss'],bibeta_w_optim_rqmc_7['loss'],bibeta_w_optim_rqmc_8['loss'],bibeta_w_optim_rqmc_9['loss'],bibeta_w_optim_rqmc_10['loss'])

# sw
loss_sw_mc = (bibeta_sw_optim_mc_1['loss'],bibeta_sw_optim_mc_2['loss'],bibeta_sw_optim_mc_3['loss'],bibeta_sw_optim_mc_4['loss'],bibeta_sw_optim_mc_5['loss'],bibeta_sw_optim_mc_6['loss'],bibeta_sw_optim_mc_7['loss'],bibeta_sw_optim_mc_8['loss'],bibeta_sw_optim_mc_9['loss'],bibeta_sw_optim_mc_10['loss'])
loss_sw_rqmc = (bibeta_sw_optim_rqmc_1['loss'],bibeta_sw_optim_rqmc_2['loss'],bibeta_sw_optim_rqmc_3['loss'],bibeta_sw_optim_rqmc_4['loss'],bibeta_sw_optim_rqmc_5['loss'],bibeta_sw_optim_rqmc_6['loss'],bibeta_sw_optim_rqmc_7['loss'],bibeta_sw_optim_rqmc_8['loss'],bibeta_sw_optim_rqmc_9['loss'],bibeta_sw_optim_rqmc_10['loss'])

# sink
loss_sink_mc = np.squeeze((bibeta_sink_optim_mc_1['loss'],bibeta_sink_optim_mc_2['loss'],bibeta_sink_optim_mc_3['loss'],bibeta_sink_optim_mc_4['loss'],bibeta_sink_optim_mc_5['loss'],bibeta_sink_optim_mc_6['loss'],bibeta_sink_optim_mc_7['loss'],bibeta_sink_optim_mc_8['loss'],bibeta_sink_optim_mc_9['loss'],bibeta_sink_optim_mc_10['loss']))
loss_sink_rqmc = np.squeeze((bibeta_sink_optim_rqmc_1['loss'],bibeta_sink_optim_rqmc_2['loss'],bibeta_sink_optim_rqmc_3['loss'],bibeta_sink_optim_rqmc_4['loss'],bibeta_sink_optim_rqmc_5['loss'],bibeta_sink_optim_rqmc_6['loss'],bibeta_sink_optim_rqmc_7['loss'],bibeta_sink_optim_rqmc_8['loss'],bibeta_sink_optim_rqmc_9['loss'],bibeta_sink_optim_rqmc_10['loss']))

# %%
# n^{1/2}
loss_mmd2_rqmc_n12 = (bibeta_mmd2_optim_rqmc_n12_1['loss'],bibeta_mmd2_optim_rqmc_n12_2['loss'],bibeta_mmd2_optim_rqmc_n12_3['loss'],bibeta_mmd2_optim_rqmc_n12_4['loss'],bibeta_mmd2_optim_rqmc_n12_5['loss'],bibeta_mmd2_optim_rqmc_n12_6['loss'],bibeta_mmd2_optim_rqmc_n12_7['loss'],bibeta_mmd2_optim_rqmc_n12_8['loss'],bibeta_mmd2_optim_rqmc_n12_9['loss'],bibeta_mmd2_optim_rqmc_n12_10['loss'])
loss_w_rqmc_n12 = (bibeta_w_optim_rqmc_n12_1['loss'],bibeta_w_optim_rqmc_n12_2['loss'],bibeta_w_optim_rqmc_n12_3['loss'],bibeta_w_optim_rqmc_n12_4['loss'],bibeta_w_optim_rqmc_n12_5['loss'],bibeta_w_optim_rqmc_n12_6['loss'],bibeta_w_optim_rqmc_n12_7['loss'],bibeta_w_optim_rqmc_n12_8['loss'],bibeta_w_optim_rqmc_n12_9['loss'],bibeta_w_optim_rqmc_n12_10['loss'])
loss_sw_rqmc_n12 = (bibeta_sw_optim_rqmc_n12_1['loss'],bibeta_sw_optim_rqmc_n12_2['loss'],bibeta_sw_optim_rqmc_n12_3['loss'],bibeta_sw_optim_rqmc_n12_4['loss'],bibeta_sw_optim_rqmc_n12_5['loss'],bibeta_sw_optim_rqmc_n12_6['loss'],bibeta_sw_optim_rqmc_n12_7['loss'],bibeta_sw_optim_rqmc_n12_8['loss'],bibeta_sw_optim_rqmc_n12_9['loss'],bibeta_sw_optim_rqmc_n12_10['loss'])
loss_sink_rqmc_n12 = (bibeta_sink_optim_rqmc_n12_1['loss'],bibeta_sink_optim_rqmc_n12_2['loss'],bibeta_sink_optim_rqmc_n12_3['loss'],bibeta_sink_optim_rqmc_n12_4['loss'],bibeta_sink_optim_rqmc_n12_5['loss'],bibeta_sink_optim_rqmc_n12_6['loss'],bibeta_sink_optim_rqmc_n12_7['loss'],bibeta_sink_optim_rqmc_n12_8['loss'],bibeta_sink_optim_rqmc_n12_9['loss'],bibeta_sink_optim_rqmc_n12_10['loss'])

# n^{2/3}
loss_mmd2_rqmc_n23 = (bibeta_mmd2_optim_rqmc_n23_1['loss'],bibeta_mmd2_optim_rqmc_n23_2['loss'],bibeta_mmd2_optim_rqmc_n23_3['loss'],bibeta_mmd2_optim_rqmc_n23_4['loss'],bibeta_mmd2_optim_rqmc_n23_5['loss'],bibeta_mmd2_optim_rqmc_n23_6['loss'],bibeta_mmd2_optim_rqmc_n23_7['loss'],bibeta_mmd2_optim_rqmc_n23_8['loss'],bibeta_mmd2_optim_rqmc_n23_9['loss'],bibeta_mmd2_optim_rqmc_n23_10['loss'])
loss_w_rqmc_n23 = (bibeta_w_optim_rqmc_n23_1['loss'],bibeta_w_optim_rqmc_n23_2['loss'],bibeta_w_optim_rqmc_n23_3['loss'],bibeta_w_optim_rqmc_n23_4['loss'],bibeta_w_optim_rqmc_n23_5['loss'],bibeta_w_optim_rqmc_n23_6['loss'],bibeta_w_optim_rqmc_n23_7['loss'],bibeta_w_optim_rqmc_n23_8['loss'],bibeta_w_optim_rqmc_n23_9['loss'],bibeta_w_optim_rqmc_n23_10['loss'])
loss_sw_rqmc_n23 = (bibeta_sw_optim_rqmc_n23_1['loss'],bibeta_sw_optim_rqmc_n23_2['loss'],bibeta_sw_optim_rqmc_n23_3['loss'],bibeta_sw_optim_rqmc_n23_4['loss'],bibeta_sw_optim_rqmc_n23_5['loss'],bibeta_sw_optim_rqmc_n23_6['loss'],bibeta_sw_optim_rqmc_n23_7['loss'],bibeta_sw_optim_rqmc_n23_8['loss'],bibeta_sw_optim_rqmc_n23_9['loss'],bibeta_sw_optim_rqmc_n23_10['loss'])
loss_sink_rqmc_n23 = (bibeta_sink_optim_rqmc_n23_1['loss'],bibeta_sink_optim_rqmc_n23_2['loss'],bibeta_sink_optim_rqmc_n23_3['loss'],bibeta_sink_optim_rqmc_n23_4['loss'],bibeta_sink_optim_rqmc_n23_5['loss'],bibeta_sink_optim_rqmc_n23_6['loss'],bibeta_sink_optim_rqmc_n23_7['loss'],bibeta_sink_optim_rqmc_n23_8['loss'],bibeta_sink_optim_rqmc_n23_9['loss'],bibeta_sink_optim_rqmc_n23_10['loss'])

# n^{3/4}
loss_mmd2_rqmc_n34 = (bibeta_mmd2_optim_rqmc_n34_1['loss'],bibeta_mmd2_optim_rqmc_n34_2['loss'],bibeta_mmd2_optim_rqmc_n34_3['loss'],bibeta_mmd2_optim_rqmc_n34_4['loss'],bibeta_mmd2_optim_rqmc_n34_5['loss'],bibeta_mmd2_optim_rqmc_n34_6['loss'],bibeta_mmd2_optim_rqmc_n34_7['loss'],bibeta_mmd2_optim_rqmc_n34_8['loss'],bibeta_mmd2_optim_rqmc_n34_9['loss'],bibeta_mmd2_optim_rqmc_n34_10['loss'])
loss_w_rqmc_n34 = (bibeta_w_optim_rqmc_n34_1['loss'],bibeta_w_optim_rqmc_n34_2['loss'],bibeta_w_optim_rqmc_n34_3['loss'],bibeta_w_optim_rqmc_n34_4['loss'],bibeta_w_optim_rqmc_n34_5['loss'],bibeta_w_optim_rqmc_n34_6['loss'],bibeta_w_optim_rqmc_n34_7['loss'],bibeta_w_optim_rqmc_n34_8['loss'],bibeta_w_optim_rqmc_n34_9['loss'],bibeta_w_optim_rqmc_n34_10['loss'])
loss_sw_rqmc_n34 = (bibeta_sw_optim_rqmc_n34_1['loss'],bibeta_sw_optim_rqmc_n34_2['loss'],bibeta_sw_optim_rqmc_n34_3['loss'],bibeta_sw_optim_rqmc_n34_4['loss'],bibeta_sw_optim_rqmc_n34_5['loss'],bibeta_sw_optim_rqmc_n34_6['loss'],bibeta_sw_optim_rqmc_n34_7['loss'],bibeta_sw_optim_rqmc_n34_8['loss'],bibeta_sw_optim_rqmc_n34_9['loss'],bibeta_sw_optim_rqmc_n34_10['loss'])
loss_sink_rqmc_n34 = (bibeta_sink_optim_rqmc_n34_1['loss'],bibeta_sink_optim_rqmc_n34_2['loss'],bibeta_sink_optim_rqmc_n34_3['loss'],bibeta_sink_optim_rqmc_n34_4['loss'],bibeta_sink_optim_rqmc_n34_5['loss'],bibeta_sink_optim_rqmc_n34_6['loss'],bibeta_sink_optim_rqmc_n34_7['loss'],bibeta_sink_optim_rqmc_n34_8['loss'],bibeta_sink_optim_rqmc_n34_9['loss'],bibeta_sink_optim_rqmc_n34_10['loss'])

# %%
def adjust_lightness(color, amount=0.5):
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], max(0, min(1, amount * c[1])), c[2])

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(36,7))
cmap = plt.get_cmap("tab10")
medianprops = dict(linewidth=2.5, color='firebrick')

bplot1 = ax1.boxplot([loss_mmd2_mc,loss_mmd2_rqmc,loss_mmd2_rqmc_n34,loss_mmd2_rqmc_n23,loss_mmd2_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot1 = ax1.boxplot([loss_mmd2_mc,loss_mmd2_rqmc,loss_mmd2_rqmc_n34,loss_mmd2_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax1.axhline(np.median(loss_mmd2_mc), linestyle='--', color='grey')
ax1.set_xticks([1,2,3,4,5])
#ax1.set_xticks([1,2,3,4])
ax1.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax1.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax1.set_ylabel(r'$|D(P^n,Q^m)|$')
ax1.set_title(r'$D=\widehat{MMD}^2_V$')

bplot2 = ax2.boxplot([loss_w_mc,loss_w_rqmc,loss_w_rqmc_n34,loss_w_rqmc_n23,loss_w_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot2 = ax2.boxplot([loss_w_mc,loss_w_rqmc,loss_w_rqmc_n34,loss_w_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax2.axhline(np.median(loss_w_mc), linestyle='--', color='grey')
ax2.set_xticks([1,2,3,4,5])
#ax2.set_xticks([1,2,3,4])
ax2.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax2.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax2.set_title(r'$D=W_{c,p}$')

bplot3 = ax3.boxplot([loss_sw_mc,loss_sw_rqmc,loss_sw_rqmc_n34,loss_sw_rqmc_n23,loss_sw_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot3 = ax3.boxplot([loss_sw_mc,loss_sw_rqmc,loss_sw_rqmc_n34,loss_sw_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax3.axhline(np.median(loss_sw_mc), linestyle='--', color='grey')
ax3.set_xticks([1,2,3,4,5])
#ax3.set_xticks([1,2,3,4])
ax3.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax3.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax3.set_title(r'$D=SW_{c,p}$')

bplot4 = ax4.boxplot([loss_sink_mc,loss_sink_rqmc,loss_sink_rqmc_n34,loss_sink_rqmc_n23,loss_sink_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot4 = ax4.boxplot([loss_sink_mc,loss_sink_rqmc,loss_sink_rqmc_n34,loss_sink_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax4.axhline(np.median(loss_sink_mc), linestyle='--', color='grey')
ax4.set_xticks([1,2,3,4,5])
#ax4.set_xticks([1,2,3,4])
ax4.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax4.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax4.set_title(r'$D=S_{c,p,\lambda}$')

cmap = plt.get_cmap("tab10")
colors = [adjust_lightness(cmap(0),1.75), adjust_lightness(cmap(2),1.75), adjust_lightness(cmap(2),1.95), adjust_lightness(cmap(2),2.15), adjust_lightness(cmap(2),2.35)]
for bplot in (bplot1, bplot2, bplot3, bplot4):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

plt.subplots_adjust(wspace=0.35, hspace=0.05)

plt.savefig('bibeta_optim_loss.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# mc (n)
mean_loss_mmd2_mc = np.mean(loss_mmd2_mc)
sd_loss_mmd2_mc = np.std(loss_mmd2_mc)
mean_loss_w_mc = np.mean(loss_w_mc)
sd_loss_w_mc = np.std(loss_w_mc)
mean_loss_sw_mc = np.mean(loss_sw_mc)
sd_loss_sw_mc = np.std(loss_sw_mc)
mean_loss_sink_mc = np.mean(loss_sink_mc)
sd_loss_sink_mc = np.std(loss_sink_mc)

# rqmc (n)
mean_loss_mmd2_rqmc = np.mean(loss_mmd2_rqmc)
sd_loss_mmd2_rqmc = np.std(loss_mmd2_rqmc)
mean_loss_w_rqmc = np.mean(loss_w_rqmc)
sd_loss_w_rqmc = np.std(loss_w_rqmc)
mean_loss_sw_rqmc = np.mean(loss_sw_rqmc)
sd_loss_sw_rqmc = np.std(loss_sw_rqmc)
mean_loss_sink_rqmc = np.mean(loss_sink_rqmc)
sd_loss_sink_rqmc = np.std(loss_sink_rqmc)

# n^{1/2}
mean_loss_mmd2_rqmc_n12 = np.mean(loss_mmd2_rqmc_n12)
sd_loss_mmd2_rqmc_n12 = np.std(loss_mmd2_rqmc_n12)
mean_loss_w_rqmc_n12 = np.mean(loss_w_rqmc_n12)
sd_loss_w_rqmc_n12 = np.std(loss_w_rqmc_n12)
mean_loss_sw_rqmc_n12 = np.mean(loss_sw_rqmc_n12)
sd_loss_sw_rqmc_n12 = np.std(loss_sw_rqmc_n12)
mean_loss_sink_rqmc_n12 = np.mean(loss_sink_rqmc_n12)
sd_loss_sink_rqmc_n12 = np.std(loss_sink_rqmc_n12)

# n^{2/3}
mean_loss_mmd2_rqmc_n23 = np.mean(loss_mmd2_rqmc_n23)
sd_loss_mmd2_rqmc_n23 = np.std(loss_mmd2_rqmc_n23)
mean_loss_w_rqmc_n23 = np.mean(loss_w_rqmc_n23)
sd_loss_w_rqmc_n23 = np.std(loss_w_rqmc_n23)
mean_loss_sw_rqmc_n23 = np.mean(loss_sw_rqmc_n23)
sd_loss_sw_rqmc_n23 = np.std(loss_sw_rqmc_n23)
mean_loss_sink_rqmc_n23 = np.mean(loss_sink_rqmc_n23)
sd_loss_sink_rqmc_n23 = np.std(loss_sink_rqmc_n23)

# n^{3/4}
mean_loss_mmd2_rqmc_n34 = np.mean(loss_mmd2_rqmc_n34)
sd_loss_mmd2_rqmc_n34 = np.std(loss_mmd2_rqmc_n34)
mean_loss_w_rqmc_n34 = np.mean(loss_w_rqmc_n34)
sd_loss_w_rqmc_n34 = np.std(loss_w_rqmc_n34)
mean_loss_sw_rqmc_n34 = np.mean(loss_sw_rqmc_n34)
sd_loss_sw_rqmc_n34 = np.std(loss_sw_rqmc_n34)
mean_loss_sink_rqmc_n34 = np.mean(loss_sink_rqmc_n34)
sd_loss_sink_rqmc_n34 = np.std(loss_sink_rqmc_n34)

# %%
print('\\begin{tabular}{| c | c | c | c | c | c | c | c | c| c | c |} ')
print('\hline')
print('& \multicolumn{2}{|c|}{MC} & \multicolumn{8}{|c|}{RQMC} \\\\')
print('\cline{2-11}')
print('& \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n^{1/2}$}& \multicolumn{2}{|c|}{$n^{2/3}$}& \multicolumn{2}{|c|}{$n^{3/4}$} \\\\')
print('\cline{2-11}')
print('D & mean & sd & mean & sd & mean & sd & mean & sd & mean & sd \\\\')
print('\hline')
print('$\widehat{MMD}^2$ &', np.format_float_scientific(mean_loss_mmd2_mc,4),'&',np.format_float_scientific(sd_loss_mmd2_mc,4),'&', np.format_float_scientific(mean_loss_mmd2_rqmc,4),'&',np.format_float_scientific(sd_loss_mmd2_rqmc,4),'&',np.format_float_scientific(mean_loss_mmd2_rqmc_n12,4),'&',np.format_float_scientific(sd_loss_mmd2_rqmc_n12,4),'&', np.format_float_scientific(mean_loss_mmd2_rqmc_n23,4),'&',np.format_float_scientific(sd_loss_mmd2_rqmc_n23,4),'&', np.format_float_scientific(mean_loss_mmd2_rqmc_n34,4),'&',np.format_float_scientific(sd_loss_mmd2_rqmc_n34,4),'\\\\')
print('$W$ &', np.format_float_scientific(mean_loss_w_mc,4),'&',np.format_float_scientific(sd_loss_w_mc,4),'&', np.format_float_scientific(mean_loss_w_rqmc,4),'&',np.format_float_scientific(sd_loss_w_rqmc,4),'&',np.format_float_scientific(mean_loss_w_rqmc_n12,4),'&',np.format_float_scientific(sd_loss_w_rqmc_n12,4),'&', np.format_float_scientific(mean_loss_w_rqmc_n23,4),'&',np.format_float_scientific(sd_loss_w_rqmc_n23,4),'&', np.format_float_scientific(mean_loss_w_rqmc_n34,4),'&',np.format_float_scientific(sd_loss_w_rqmc_n34,4),'\\\\')
print('$SW$ &', np.format_float_scientific(mean_loss_sw_mc,4),'&',np.format_float_scientific(sd_loss_sw_mc,4),'&',np.format_float_scientific(mean_loss_sw_rqmc,4),'&',np.format_float_scientific(sd_loss_sw_rqmc,4),'&',np.format_float_scientific(mean_loss_sw_rqmc_n12,4),'&',np.format_float_scientific(sd_loss_sw_rqmc_n12,4),'&',np.format_float_scientific(mean_loss_sw_rqmc_n23,4),'&',np.format_float_scientific(sd_loss_sw_rqmc_n23,4),'&',np.format_float_scientific(mean_loss_sw_rqmc_n34,4),'&',np.format_float_scientific(sd_loss_sw_rqmc_n34,4),'\\\\')
print('$S$ &', np.format_float_scientific(mean_loss_sink_mc,4),'&',np.format_float_scientific(sd_loss_sink_mc,4),'&', np.format_float_scientific(mean_loss_sink_rqmc,4),'&',np.format_float_scientific(sd_loss_sink_rqmc,4),'&',np.format_float_scientific(mean_loss_sink_rqmc_n12,4),'&',np.format_float_scientific(sd_loss_sink_rqmc_n12,4),'&', np.format_float_scientific(mean_loss_sink_rqmc_n23,4),'&',np.format_float_scientific(sd_loss_sink_rqmc_n23,4),'&', np.format_float_scientific(mean_loss_sink_rqmc_n34,4),'&',np.format_float_scientific(sd_loss_sink_rqmc_n34,4),'\\\\')
print('\hline')
print('\end{tabular}')
# Out:
# \begin{tabular}{| c | c | c | c | c | c | c | c | c| c | c |}
# \hline
# & \multicolumn{2}{|c|}{MC} & \multicolumn{8}{|c|}{RQMC} \\
# \cline{2-11}
# & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n^{1/2}$}& \multicolumn{2}{|c|}{$n^{2/3}$}& \multicolumn{2}{|c|}{$n^{3/4}$} \\
# \cline{2-11}
# D & mean & sd & mean & sd & mean & sd & mean & sd & mean & sd \\
# \hline
# $\widehat{MMD}^2$ & 3.1980e-05 & 2.9149e-05 & 3.3231e-05 & 2.3650e-05 & 1.1799e-04 & 6.1449e-05 & 2.879e-05 & 1.6703e-05 & 4.3274e-05 & 3.8289e-05 \\
# $W$ & 2.1602e-02 & 3.5878e-03 & 1.9474e-02 & 1.9306e-03 & 3.3068e-02 & 5.3232e-03 & 2.6643e-02 & 5.7061e-03 & 2.0313e-02 & 3.3005e-03 \\
# $SW$ & 1.1744e-01 & 6.6676e-03 & 8.7928e-02 & 8.2818e-03 & 1.3327e-01 & 1.9918e-02 & 1.2698e-01 & 1.8902e-02 & 1.051e-01 & 1.3368e-02 \\
# $S$ & 2.6375e-04 & 1.2540e-04 & 1.7577e-04 & 6.7209e-05 & 5.4897e-04 & 1.6107e-04 & 6.1498e-04 & 5.6967e-04 & 1.7684e-04 & 1.3442e-04 \\
# \hline
# \end{tabular}

# %% [markdown]
# Optimisation time in hours after 3000 iterations with $m=2^{16}$, $m\text{_}sub=2^{10}$ and $n=2^9$, $n=(2^9)^{1/2}$, $n=(2^9)^{2/3}$ or $n=(2^9)^{3/4}$ for $\widehat{\text{MMD}}^2$ ($l=1.5d^{1/2}$), 1-Wasserstein distance, 1-sliced Wasserstein distance (100 projections), and Sinkhorn divergence ($\lambda=5d$) using RQMC:

# %%
SMALL_SIZE = 30
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
# mmd^2
time_mmd2_mc = np.divide((bibeta_mmd2_optim_mc_1['time'],bibeta_mmd2_optim_mc_2['time'],bibeta_mmd2_optim_mc_3['time'],bibeta_mmd2_optim_mc_4['time'],bibeta_mmd2_optim_mc_5['time'],bibeta_mmd2_optim_mc_6['time'],bibeta_mmd2_optim_mc_7['time'],bibeta_mmd2_optim_mc_8['time'],bibeta_mmd2_optim_mc_9['time'],bibeta_mmd2_optim_mc_10['time']),60**2)
time_mmd2_rqmc = np.divide((bibeta_mmd2_optim_rqmc_1['time'],bibeta_mmd2_optim_rqmc_2['time'],bibeta_mmd2_optim_rqmc_3['time'],bibeta_mmd2_optim_rqmc_4['time'],bibeta_mmd2_optim_rqmc_5['time'],bibeta_mmd2_optim_rqmc_6['time'],bibeta_mmd2_optim_rqmc_7['time'],bibeta_mmd2_optim_rqmc_8['time'],bibeta_mmd2_optim_rqmc_9['time'],bibeta_mmd2_optim_rqmc_10['time']),60**2)

# w
time_w_mc = np.divide((bibeta_w_optim_mc_1['time'],bibeta_w_optim_mc_2['time'],bibeta_w_optim_mc_3['time'],bibeta_w_optim_mc_4['time'],bibeta_w_optim_mc_5['time'],bibeta_w_optim_mc_6['time'],bibeta_w_optim_mc_7['time'],bibeta_w_optim_mc_8['time'],bibeta_w_optim_mc_9['time'],bibeta_w_optim_mc_10['time']),60**2)
time_w_rqmc = np.divide((bibeta_w_optim_rqmc_1['time'],bibeta_w_optim_rqmc_2['time'],bibeta_w_optim_rqmc_3['time'],bibeta_w_optim_rqmc_4['time'],bibeta_w_optim_rqmc_5['time'],bibeta_w_optim_rqmc_6['time'],bibeta_w_optim_rqmc_7['time'],bibeta_w_optim_rqmc_8['time'],bibeta_w_optim_rqmc_9['time'],bibeta_w_optim_rqmc_10['time']),60**2)

# sw
time_sw_mc = np.divide((bibeta_sw_optim_mc_1['time'],bibeta_sw_optim_mc_2['time'],bibeta_sw_optim_mc_3['time'],bibeta_sw_optim_mc_4['time'],bibeta_sw_optim_mc_5['time'],bibeta_sw_optim_mc_6['time'],bibeta_sw_optim_mc_7['time'],bibeta_sw_optim_mc_8['time'],bibeta_sw_optim_mc_9['time'],bibeta_sw_optim_mc_10['time']),60**2)
time_sw_rqmc = np.divide((bibeta_sw_optim_rqmc_1['time'],bibeta_sw_optim_rqmc_2['time'],bibeta_sw_optim_rqmc_3['time'],bibeta_sw_optim_rqmc_4['time'],bibeta_sw_optim_rqmc_5['time'],bibeta_sw_optim_rqmc_6['time'],bibeta_sw_optim_rqmc_7['time'],bibeta_sw_optim_rqmc_8['time'],bibeta_sw_optim_rqmc_9['time'],bibeta_sw_optim_rqmc_10['time']),60**2)

# s
time_sink_mc = np.divide((bibeta_sink_optim_mc_1['time'],bibeta_sink_optim_mc_2['time'],bibeta_sink_optim_mc_3['time'],bibeta_sink_optim_mc_4['time'],bibeta_sink_optim_mc_5['time'],bibeta_sink_optim_mc_6['time'],bibeta_sink_optim_mc_7['time'],bibeta_sink_optim_mc_8['time'],bibeta_sink_optim_mc_9['time'],bibeta_sink_optim_mc_10['time']),60**2)
time_sink_rqmc = np.divide((bibeta_sink_optim_rqmc_1['time'],bibeta_sink_optim_rqmc_2['time'],bibeta_sink_optim_rqmc_3['time'],bibeta_sink_optim_rqmc_4['time'],bibeta_sink_optim_rqmc_5['time'],bibeta_sink_optim_rqmc_6['time'],bibeta_sink_optim_rqmc_7['time'],bibeta_sink_optim_rqmc_8['time'],bibeta_sink_optim_rqmc_9['time'],bibeta_sink_optim_rqmc_10['time']),60**2)

# %%
# n^{1/2}
time_mmd2_rqmc_n12 = np.divide((bibeta_mmd2_optim_rqmc_n12_1['time'],bibeta_mmd2_optim_rqmc_n12_2['time'],bibeta_mmd2_optim_rqmc_n12_3['time'],bibeta_mmd2_optim_rqmc_n12_4['time'],bibeta_mmd2_optim_rqmc_n12_5['time'],bibeta_mmd2_optim_rqmc_n12_6['time'],bibeta_mmd2_optim_rqmc_n12_7['time'],bibeta_mmd2_optim_rqmc_n12_8['time'],bibeta_mmd2_optim_rqmc_n12_9['time'],bibeta_mmd2_optim_rqmc_n12_10['time']),60**2)
time_w_rqmc_n12 = np.divide((bibeta_w_optim_rqmc_n12_1['time'],bibeta_w_optim_rqmc_n12_2['time'],bibeta_w_optim_rqmc_n12_3['time'],bibeta_w_optim_rqmc_n12_4['time'],bibeta_w_optim_rqmc_n12_5['time'],bibeta_w_optim_rqmc_n12_6['time'],bibeta_w_optim_rqmc_n12_7['time'],bibeta_w_optim_rqmc_n12_8['time'],bibeta_w_optim_rqmc_n12_9['time'],bibeta_w_optim_rqmc_n12_10['time']),60**2)
time_sw_rqmc_n12 = np.divide((bibeta_sw_optim_rqmc_n12_1['time'],bibeta_sw_optim_rqmc_n12_2['time'],bibeta_sw_optim_rqmc_n12_3['time'],bibeta_sw_optim_rqmc_n12_4['time'],bibeta_sw_optim_rqmc_n12_5['time'],bibeta_sw_optim_rqmc_n12_6['time'],bibeta_sw_optim_rqmc_n12_7['time'],bibeta_sw_optim_rqmc_n12_8['time'],bibeta_sw_optim_rqmc_n12_9['time'],bibeta_sw_optim_rqmc_n12_10['time']),60**2)
time_sink_rqmc_n12 = np.divide((bibeta_sink_optim_rqmc_n12_1['time'],bibeta_sink_optim_rqmc_n12_2['time'],bibeta_sink_optim_rqmc_n12_3['time'],bibeta_sink_optim_rqmc_n12_4['time'],bibeta_sink_optim_rqmc_n12_5['time'],bibeta_sink_optim_rqmc_n12_6['time'],bibeta_sink_optim_rqmc_n12_7['time'],bibeta_sink_optim_rqmc_n12_8['time'],bibeta_sink_optim_rqmc_n12_9['time'],bibeta_sink_optim_rqmc_n12_10['time']),60**2)

# n^{2/3}
time_mmd2_rqmc_n23 = np.divide((bibeta_mmd2_optim_rqmc_n23_1['time'],bibeta_mmd2_optim_rqmc_n23_2['time'],bibeta_mmd2_optim_rqmc_n23_3['time'],bibeta_mmd2_optim_rqmc_n23_4['time'],bibeta_mmd2_optim_rqmc_n23_5['time'],bibeta_mmd2_optim_rqmc_n23_6['time'],bibeta_mmd2_optim_rqmc_n23_7['time'],bibeta_mmd2_optim_rqmc_n23_8['time'],bibeta_mmd2_optim_rqmc_n23_9['time'],bibeta_mmd2_optim_rqmc_n23_10['time']),60**2)
time_w_rqmc_n23 = np.divide((bibeta_w_optim_rqmc_n23_1['time'],bibeta_w_optim_rqmc_n23_2['time'],bibeta_w_optim_rqmc_n23_3['time'],bibeta_w_optim_rqmc_n23_4['time'],bibeta_w_optim_rqmc_n23_5['time'],bibeta_w_optim_rqmc_n23_6['time'],bibeta_w_optim_rqmc_n23_7['time'],bibeta_w_optim_rqmc_n23_8['time'],bibeta_w_optim_rqmc_n23_9['time'],bibeta_w_optim_rqmc_n23_10['time']),60**2)
time_sw_rqmc_n23 = np.divide((bibeta_sw_optim_rqmc_n23_1['time'],bibeta_sw_optim_rqmc_n23_2['time'],bibeta_sw_optim_rqmc_n23_3['time'],bibeta_sw_optim_rqmc_n23_4['time'],bibeta_sw_optim_rqmc_n23_5['time'],bibeta_sw_optim_rqmc_n23_6['time'],bibeta_sw_optim_rqmc_n23_7['time'],bibeta_sw_optim_rqmc_n23_8['time'],bibeta_sw_optim_rqmc_n23_9['time'],bibeta_sw_optim_rqmc_n23_10['time']),60**2)
time_sink_rqmc_n23 = np.divide((bibeta_sink_optim_rqmc_n23_1['time'],bibeta_sink_optim_rqmc_n23_2['time'],bibeta_sink_optim_rqmc_n23_3['time'],bibeta_sink_optim_rqmc_n23_4['time'],bibeta_sink_optim_rqmc_n23_5['time'],bibeta_sink_optim_rqmc_n23_6['time'],bibeta_sink_optim_rqmc_n23_7['time'],bibeta_sink_optim_rqmc_n23_8['time'],bibeta_sink_optim_rqmc_n23_9['time'],bibeta_sink_optim_rqmc_n23_10['time']),60**2)

# n^{3/4}
time_mmd2_rqmc_n34 = np.divide((bibeta_mmd2_optim_rqmc_n12_1['time'],bibeta_mmd2_optim_rqmc_n34_2['time'],bibeta_mmd2_optim_rqmc_n34_3['time'],bibeta_mmd2_optim_rqmc_n34_4['time'],bibeta_mmd2_optim_rqmc_n34_5['time'],bibeta_mmd2_optim_rqmc_n12_6['time'],bibeta_mmd2_optim_rqmc_n34_7['time'],bibeta_mmd2_optim_rqmc_n34_8['time'],bibeta_mmd2_optim_rqmc_n34_9['time'],bibeta_mmd2_optim_rqmc_n34_10['time']),60**2)
time_w_rqmc_n34 = np.divide((bibeta_w_optim_rqmc_n34_1['time'],bibeta_w_optim_rqmc_n34_2['time'],bibeta_w_optim_rqmc_n34_3['time'],bibeta_w_optim_rqmc_n34_4['time'],bibeta_w_optim_rqmc_n34_5['time'],bibeta_w_optim_rqmc_n34_6['time'],bibeta_w_optim_rqmc_n34_7['time'],bibeta_w_optim_rqmc_n34_8['time'],bibeta_w_optim_rqmc_n34_9['time'],bibeta_w_optim_rqmc_n34_10['time']),60**2)
time_sw_rqmc_n34 = np.divide((bibeta_sw_optim_rqmc_n34_1['time'],bibeta_sw_optim_rqmc_n34_2['time'],bibeta_sw_optim_rqmc_n34_3['time'],bibeta_sw_optim_rqmc_n34_4['time'],bibeta_sw_optim_rqmc_n34_5['time'],bibeta_sw_optim_rqmc_n34_6['time'],bibeta_sw_optim_rqmc_n34_7['time'],bibeta_sw_optim_rqmc_n34_8['time'],bibeta_sw_optim_rqmc_n34_9['time'],bibeta_sw_optim_rqmc_n34_10['time']),60**2)
time_sink_rqmc_n34 = np.divide((bibeta_sink_optim_rqmc_n34_1['time'],bibeta_sink_optim_rqmc_n34_2['time'],bibeta_sink_optim_rqmc_n34_3['time'],bibeta_sink_optim_rqmc_n34_4['time'],bibeta_sink_optim_rqmc_n34_5['time'],bibeta_sink_optim_rqmc_n34_6['time'],bibeta_sink_optim_rqmc_n34_7['time'],bibeta_sink_optim_rqmc_n34_8['time'],bibeta_sink_optim_rqmc_n34_9['time'],bibeta_sink_optim_rqmc_n34_10['time']),60**2)

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(32,8), sharey='row')
cmap = plt.get_cmap("tab10")
medianprops = dict(linewidth=2.5, color='firebrick')

bplot1 = ax1.boxplot([time_mmd2_mc,time_mmd2_rqmc,time_mmd2_rqmc_n34,time_mmd2_rqmc_n23,time_mmd2_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot1 = ax1.boxplot([time_mmd2_mc,time_mmd2_rqmc,time_mmd2_rqmc_n34,time_mmd2_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax1.axhline(np.median(time_mmd2_mc), linestyle='--', color='grey')
ax1.set_xticks([1,2,3,4,5])
#ax1.set_xticks([1,2,3,4])
ax1.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax1.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax1.set_ylabel('computation time [hours]')
ax1.set_title(r'$D=\widehat{MMD}^2_V$')

bplot2 = ax2.boxplot([time_w_mc,time_w_rqmc,time_w_rqmc_n34,time_w_rqmc_n23,time_w_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot2 = ax2.boxplot([time_w_mc,time_w_rqmc,time_w_rqmc_n34,time_w_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax2.axhline(np.median(time_w_mc), linestyle='--', color='grey')
ax2.set_xticks([1,2,3,4,5])
#ax2.set_xticks([1,2,3,4])
ax2.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax2.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax2.set_title(r'$D=W_{c,p}$')

bplot3 = ax3.boxplot([time_sw_mc,time_sw_rqmc,time_sw_rqmc_n34,time_sw_rqmc_n23,time_sw_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot3 = ax3.boxplot([time_sw_mc,time_sw_rqmc,time_sw_rqmc_n34,time_sw_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax3.axhline(np.median(time_sw_mc), linestyle='--', color='grey')
ax3.set_xticks([1,2,3,4,5])
#ax3.set_xticks([1,2,3,4])
ax3.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax3.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax3.set_title(r'$D=SW_{c,p}$')

bplot4 = ax4.boxplot([time_sink_mc,time_sink_rqmc,time_sink_rqmc_n34,time_sink_rqmc_n23,time_sink_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot4 = ax4.boxplot([time_sink_mc,time_sink_rqmc,time_sink_rqmc_n34,time_sink_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax4.axhline(np.median(time_sink_mc), linestyle='--', color='grey')
ax4.set_xticks([1,2,3,4,5])
#ax4.set_xticks([1,2,3,4])
ax4.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax4.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax4.set_title(r'$D=S_{c,p,\lambda}$')

cmap = plt.get_cmap("tab10")
colors = [adjust_lightness(cmap(0),1.75), adjust_lightness(cmap(2),1.75), adjust_lightness(cmap(2),1.95), adjust_lightness(cmap(2),2.15), adjust_lightness(cmap(2),2.35)]
for bplot in (bplot1, bplot2, bplot3, bplot4):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

plt.subplots_adjust(wspace=0.15, hspace=0.05)

plt.savefig('bibeta_optim_time.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %%
# mc (n)
mean_time_mmd2_mc = np.mean(time_mmd2_mc)
sd_time_mmd2_mc = np.std(time_mmd2_mc)
mean_time_w_mc = np.mean(time_w_mc)
sd_time_w_mc = np.std(time_w_mc)
mean_time_sw_mc = np.mean(time_sw_mc)
sd_time_sw_mc = np.std(time_sw_mc)
mean_time_sink_mc = np.mean(time_sink_mc)
sd_time_sink_mc = np.std(time_sink_mc)

# rqmc (n)
mean_time_mmd2_rqmc = np.mean(time_mmd2_rqmc)
sd_time_mmd2_rqmc = np.std(time_mmd2_rqmc)
mean_time_w_rqmc = np.mean(time_w_rqmc)
sd_time_w_rqmc = np.std(time_w_rqmc)
mean_time_sw_rqmc = np.mean(time_sw_rqmc)
sd_time_sw_rqmc = np.std(time_sw_rqmc)
mean_time_sink_rqmc = np.mean(time_sink_rqmc)
sd_time_sink_rqmc = np.std(time_sink_rqmc)

# n^{1/2}
mean_time_mmd2_rqmc_n12 = np.mean(time_mmd2_rqmc_n12)
sd_time_mmd2_rqmc_n12 = np.std(time_mmd2_rqmc_n12)
mean_time_w_rqmc_n12 = np.mean(time_w_rqmc_n12)
sd_time_w_rqmc_n12 = np.std(time_w_rqmc_n12)
mean_time_sw_rqmc_n12 = np.mean(time_sw_rqmc_n12)
sd_time_sw_rqmc_n12 = np.std(time_sw_rqmc_n12)
mean_time_sink_rqmc_n12 = np.mean(time_sink_rqmc_n12)
sd_time_sink_rqmc_n12 = np.std(time_sink_rqmc_n12)

# n^{2/3}
mean_time_mmd2_rqmc_n23 = np.mean(time_mmd2_rqmc_n23)
sd_time_mmd2_rqmc_n23 = np.std(time_mmd2_rqmc_n23)
mean_time_w_rqmc_n23 = np.mean(time_w_rqmc_n23)
sd_time_w_rqmc_n23 = np.std(time_w_rqmc_n23)
mean_time_sw_rqmc_n23 = np.mean(time_sw_rqmc_n23)
sd_time_sw_rqmc_n23 = np.std(time_sw_rqmc_n23)
mean_time_sink_rqmc_n23 = np.mean(time_sink_rqmc_n23)
sd_time_sink_rqmc_n23 = np.std(time_sink_rqmc_n23)

# n^{3/4}
mean_time_mmd2_rqmc_n34 = np.mean(time_mmd2_rqmc_n34)
sd_time_mmd2_rqmc_n34 = np.std(time_mmd2_rqmc_n34)
mean_time_w_rqmc_n34 = np.mean(time_w_rqmc_n34)
sd_time_w_rqmc_n34 = np.std(time_w_rqmc_n34)
mean_time_sw_rqmc_n34 = np.mean(time_sw_rqmc_n34)
sd_time_sw_rqmc_n34 = np.std(time_sw_rqmc_n34)
mean_time_sink_rqmc_n34 = np.mean(time_sink_rqmc_n34)
sd_time_sink_rqmc_n34 = np.std(time_sink_rqmc_n34)

# %%
print('\\begin{tabular}{| c | c | c | c | c | c | c | c | c| c | c |} ')
print('\hline')
print('& \multicolumn{2}{|c|}{MC} & \multicolumn{8}{|c|}{RQMC} \\\\')
print('\cline{2-11}')
print('\hline')
print('& \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n^{1/2}$}& \multicolumn{2}{|c|}{$n^{2/3}$}& \multicolumn{2}{|c|}{$n^{3/4}$} \\\\')
print('\cline{2-11}')
print('D & mean & sd & mean & sd & mean & sd & mean & sd & mean & sd \\\\')
print('\hline')
print('$\widehat{MMD}^2$ &', np.round(mean_time_mmd2_mc,4),'&',np.round(sd_time_mmd2_mc,4),'&', np.round(mean_time_mmd2_rqmc,4),'&',np.round(sd_time_mmd2_rqmc,4),'&',np.round(mean_time_mmd2_rqmc_n12,4),'&',np.round(sd_time_mmd2_rqmc_n12,4),'&', np.round(mean_time_mmd2_rqmc_n23,4),'&',np.round(sd_time_mmd2_rqmc_n23,4),'&', np.round(mean_time_mmd2_rqmc_n34,4),'&',np.round(sd_time_mmd2_rqmc_n34,4),'\\\\')
print('$W$ &', np.round(mean_time_w_mc,4),'&',np.round(sd_time_w_mc,4),'&', np.round(mean_time_w_rqmc,4),'&',np.round(sd_time_w_rqmc,4),'&',np.round(mean_time_w_rqmc_n12,4),'&',np.round(sd_time_w_rqmc_n12,4),'&', np.round(mean_time_w_rqmc_n23,4),'&',np.round(sd_time_w_rqmc_n23,4),'&', np.round(mean_time_w_rqmc_n34,4),'&',np.round(sd_time_w_rqmc_n34,4),'\\\\')
print('$SW$ &', np.round(mean_time_sw_mc,4),'&',np.round(sd_time_sw_mc,4),'&', np.round(mean_time_sw_rqmc,4),'&',np.round(sd_time_sw_rqmc,4),'&',np.round(mean_time_sw_rqmc_n12,4),'&',np.round(sd_time_sw_rqmc_n12,4),'&', np.round(mean_time_sw_rqmc_n23,4),'&',np.round(sd_time_sw_rqmc_n23,4),'&', np.round(mean_time_sw_rqmc_n34,4),'&',np.round(sd_time_sw_rqmc_n34,4),'\\\\')
print('$S$ &', np.round(mean_time_sink_mc,4),'&',np.round(sd_time_sink_mc,4),'&', np.round(mean_time_sink_rqmc,4),'&',np.round(sd_time_sink_rqmc,4),'&',np.round(mean_time_sink_rqmc_n12,4),'&',np.round(sd_time_sink_rqmc_n12,4),'&', np.round(mean_time_sink_rqmc_n23,4),'&',np.round(sd_time_sink_rqmc_n23,4),'&', np.round(mean_time_sink_rqmc_n34,4),'&',np.round(sd_time_sink_rqmc_n34,4),'\\\\')
print('\hline')
print('\end{tabular}')
# Out:
# \begin{tabular}{| c | c | c | c | c | c | c | c | c| c | c |}
# \hline
# & \multicolumn{2}{|c|}{MC} & \multicolumn{8}{|c|}{RQMC} \\
# \cline{2-11}
# \hline
# & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n^{1/2}$}& \multicolumn{2}{|c|}{$n^{2/3}$}& \multicolumn{2}{|c|}{$n^{3/4}$} \\
# \cline{2-11}
# D & mean & sd & mean & sd & mean & sd & mean & sd & mean & sd \\
# \hline
# $\widehat{MMD}^2$ & 2.4954 & 0.3258 & 8.0354 & 0.3671 & 2.0111 & 0.056 & 2.5895 & 0.131 & 2.765 & 0.3607 \\
# $W$ & 5.0066 & 0.6543 & 9.926 & 0.2826 & 0.7634 & 0.0269 & 1.6656 & 0.0963 & 2.3425 & 0.2156 \\
# $SW$ & 1.4955 & 0.0986 & 6.364 & 0.1622 & 1.6207 & 0.071 & 2.0519 & 0.1338 & 2.5336 & 0.0608 \\
# $S$ & 7.7123 & 0.4535 & 14.143 & 1.1534 & 4.7237 & 0.6174 & 6.0639 & 0.2132 & 6.7752 & 0.6426 \\
# \hline
# \end{tabular}

# %% [markdown]
# Optimisation estimates in hours after 3000 iterations with $m=2^{16}$, $m\text{_}sub=2^{10}$ and $n=2^9$, $n=(2^9)^{1/2}$, $n=(2^9)^{2/3}$ or $n=(2^9)^{3/4}$ for $\widehat{\text{MMD}}^2$ ($l=1.5d^{1/2}$), 1-Wasserstein distance, 1-sliced Wasserstein distance (100 projections), and Sinkhorn divergence ($\lambda=5d$) using RQMC:

# %%
theta = np.ones(5)

# %%
# mmd^2
theta_mmd2_mc = np.vstack([bibeta_mmd2_optim_mc_1['theta'],bibeta_mmd2_optim_mc_2['theta'],bibeta_mmd2_optim_mc_3['theta'],bibeta_mmd2_optim_mc_4['theta'],bibeta_mmd2_optim_mc_5['theta'],bibeta_mmd2_optim_mc_6['theta'],bibeta_mmd2_optim_mc_7['theta'],bibeta_mmd2_optim_mc_8['theta'],bibeta_mmd2_optim_mc_9['theta'],bibeta_mmd2_optim_mc_10['theta']])
theta_mmd2_rqmc = np.vstack([bibeta_mmd2_optim_rqmc_1['theta'],bibeta_mmd2_optim_rqmc_2['theta'],bibeta_mmd2_optim_rqmc_3['theta'],bibeta_mmd2_optim_rqmc_4['theta'],bibeta_mmd2_optim_rqmc_5['theta'],bibeta_mmd2_optim_rqmc_6['theta'],bibeta_mmd2_optim_rqmc_7['theta'],bibeta_mmd2_optim_rqmc_8['theta'],bibeta_mmd2_optim_rqmc_9['theta'],bibeta_mmd2_optim_rqmc_10['theta']])

# w
theta_w_mc = np.vstack([bibeta_w_optim_mc_1['theta'],bibeta_w_optim_mc_2['theta'],bibeta_w_optim_mc_3['theta'],bibeta_w_optim_mc_4['theta'],bibeta_w_optim_mc_5['theta'],bibeta_w_optim_mc_6['theta'],bibeta_w_optim_mc_7['theta'],bibeta_w_optim_mc_8['theta'],bibeta_w_optim_mc_9['theta'],bibeta_w_optim_mc_10['theta']])
theta_w_rqmc = np.vstack([bibeta_w_optim_rqmc_1['theta'],bibeta_w_optim_rqmc_2['theta'],bibeta_w_optim_rqmc_3['theta'],bibeta_w_optim_rqmc_4['theta'],bibeta_w_optim_rqmc_5['theta'],bibeta_w_optim_rqmc_6['theta'],bibeta_w_optim_rqmc_7['theta'],bibeta_w_optim_rqmc_8['theta'],bibeta_w_optim_rqmc_9['theta'],bibeta_w_optim_rqmc_10['theta']])

# sw
theta_sw_mc = np.vstack([bibeta_sw_optim_mc_1['theta'],bibeta_sw_optim_mc_2['theta'],bibeta_sw_optim_mc_3['theta'],bibeta_sw_optim_mc_4['theta'],bibeta_sw_optim_mc_5['theta'],bibeta_sw_optim_mc_6['theta'],bibeta_sw_optim_mc_7['theta'],bibeta_sw_optim_mc_8['theta'],bibeta_sw_optim_mc_9['theta'],bibeta_sw_optim_mc_10['theta']])
theta_sw_rqmc = np.vstack([bibeta_sw_optim_rqmc_1['theta'],bibeta_sw_optim_rqmc_2['theta'],bibeta_sw_optim_rqmc_3['theta'],bibeta_sw_optim_rqmc_4['theta'],bibeta_sw_optim_rqmc_5['theta'],bibeta_sw_optim_rqmc_6['theta'],bibeta_sw_optim_rqmc_7['theta'],bibeta_sw_optim_rqmc_8['theta'],bibeta_sw_optim_rqmc_9['theta'],bibeta_sw_optim_rqmc_10['theta']])

# s
theta_sink_mc = np.vstack([bibeta_sink_optim_mc_1['theta'],bibeta_sink_optim_mc_2['theta'],bibeta_sink_optim_mc_3['theta'],bibeta_sink_optim_mc_4['theta'],bibeta_sink_optim_mc_5['theta'],bibeta_sink_optim_mc_6['theta'],bibeta_sink_optim_mc_7['theta'],bibeta_sink_optim_mc_8['theta'],bibeta_sink_optim_mc_9['theta'],bibeta_sink_optim_mc_10['theta']])
theta_sink_rqmc = np.vstack([bibeta_sink_optim_rqmc_1['theta'],bibeta_sink_optim_rqmc_2['theta'],bibeta_sink_optim_rqmc_3['theta'],bibeta_sink_optim_rqmc_4['theta'],bibeta_sink_optim_rqmc_5['theta'],bibeta_sink_optim_rqmc_6['theta'],bibeta_sink_optim_rqmc_7['theta'],bibeta_sink_optim_rqmc_8['theta'],bibeta_sink_optim_rqmc_9['theta'],bibeta_sink_optim_rqmc_10['theta']])

# %%
# n^{1/2}
theta_mmd2_rqmc_n12 = np.vstack([bibeta_mmd2_optim_rqmc_n12_1['theta'],bibeta_mmd2_optim_rqmc_n12_2['theta'],bibeta_mmd2_optim_rqmc_n12_3['theta'],bibeta_mmd2_optim_rqmc_n12_4['theta'],bibeta_mmd2_optim_rqmc_n12_5['theta'],bibeta_mmd2_optim_rqmc_n12_6['theta'],bibeta_mmd2_optim_rqmc_n12_7['theta'],bibeta_mmd2_optim_rqmc_n12_8['theta'],bibeta_mmd2_optim_rqmc_n12_9['theta'],bibeta_mmd2_optim_rqmc_n12_10['theta']])
theta_w_rqmc_n12 = np.vstack([bibeta_w_optim_rqmc_n12_1['theta'],bibeta_w_optim_rqmc_n12_2['theta'],bibeta_w_optim_rqmc_n12_3['theta'],bibeta_w_optim_rqmc_n12_4['theta'],bibeta_w_optim_rqmc_n12_5['theta'],bibeta_w_optim_rqmc_n12_6['theta'],bibeta_w_optim_rqmc_n12_7['theta'],bibeta_w_optim_rqmc_n12_8['theta'],bibeta_w_optim_rqmc_n12_9['theta'],bibeta_w_optim_rqmc_n12_10['theta']])
theta_sw_rqmc_n12 = np.vstack([bibeta_sw_optim_rqmc_n12_1['theta'],bibeta_sw_optim_rqmc_n12_2['theta'],bibeta_sw_optim_rqmc_n12_3['theta'],bibeta_sw_optim_rqmc_n12_4['theta'],bibeta_sw_optim_rqmc_n12_5['theta'],bibeta_sw_optim_rqmc_n12_6['theta'],bibeta_sw_optim_rqmc_n12_7['theta'],bibeta_sw_optim_rqmc_n12_8['theta'],bibeta_sw_optim_rqmc_n12_9['theta'],bibeta_sw_optim_rqmc_n12_10['theta']])
theta_sink_rqmc_n12 = np.vstack([bibeta_sink_optim_rqmc_n12_1['theta'],bibeta_sink_optim_rqmc_n12_2['theta'],bibeta_sink_optim_rqmc_n12_3['theta'],bibeta_sink_optim_rqmc_n12_4['theta'],bibeta_sink_optim_rqmc_n12_5['theta'],bibeta_sink_optim_rqmc_n12_6['theta'],bibeta_sink_optim_rqmc_n12_7['theta'],bibeta_sink_optim_rqmc_n12_8['theta'],bibeta_sink_optim_rqmc_n12_9['theta'],bibeta_sink_optim_rqmc_n12_10['theta']])

# n^{2/3}
theta_mmd2_rqmc_n23 = np.vstack([bibeta_mmd2_optim_rqmc_n23_1['theta'],bibeta_mmd2_optim_rqmc_n23_2['theta'],bibeta_mmd2_optim_rqmc_n23_3['theta'],bibeta_mmd2_optim_rqmc_n23_4['theta'],bibeta_mmd2_optim_rqmc_n23_5['theta'],bibeta_mmd2_optim_rqmc_n23_6['theta'],bibeta_mmd2_optim_rqmc_n23_7['theta'],bibeta_mmd2_optim_rqmc_n23_8['theta'],bibeta_mmd2_optim_rqmc_n23_9['theta'],bibeta_mmd2_optim_rqmc_n23_10['theta']])
theta_w_rqmc_n23 = np.vstack([bibeta_w_optim_rqmc_n23_1['theta'],bibeta_w_optim_rqmc_n23_2['theta'],bibeta_w_optim_rqmc_n23_3['theta'],bibeta_w_optim_rqmc_n23_4['theta'],bibeta_w_optim_rqmc_n23_5['theta'],bibeta_w_optim_rqmc_n23_6['theta'],bibeta_w_optim_rqmc_n23_7['theta'],bibeta_w_optim_rqmc_n23_8['theta'],bibeta_w_optim_rqmc_n23_9['theta'],bibeta_w_optim_rqmc_n23_10['theta']])
theta_sw_rqmc_n23 = np.vstack([bibeta_sw_optim_rqmc_n23_1['theta'],bibeta_sw_optim_rqmc_n23_2['theta'],bibeta_sw_optim_rqmc_n23_3['theta'],bibeta_sw_optim_rqmc_n23_4['theta'],bibeta_sw_optim_rqmc_n23_5['theta'],bibeta_sw_optim_rqmc_n23_6['theta'],bibeta_sw_optim_rqmc_n23_7['theta'],bibeta_sw_optim_rqmc_n23_8['theta'],bibeta_sw_optim_rqmc_n23_9['theta'],bibeta_sw_optim_rqmc_n23_10['theta']])
theta_sink_rqmc_n23 = np.vstack([bibeta_sink_optim_rqmc_n23_1['theta'],bibeta_sink_optim_rqmc_n23_2['theta'],bibeta_sink_optim_rqmc_n23_3['theta'],bibeta_sink_optim_rqmc_n23_4['theta'],bibeta_sink_optim_rqmc_n23_5['theta'],bibeta_sink_optim_rqmc_n23_6['theta'],bibeta_sink_optim_rqmc_n23_7['theta'],bibeta_sink_optim_rqmc_n23_8['theta'],bibeta_sink_optim_rqmc_n23_9['theta'],bibeta_sink_optim_rqmc_n23_10['theta']])

# n^{3/4}
theta_mmd2_rqmc_n34 = np.vstack([bibeta_mmd2_optim_rqmc_n34_1['theta'],bibeta_mmd2_optim_rqmc_n34_2['theta'],bibeta_mmd2_optim_rqmc_n34_3['theta'],bibeta_mmd2_optim_rqmc_n34_4['theta'],bibeta_mmd2_optim_rqmc_n34_5['theta'],bibeta_mmd2_optim_rqmc_n34_6['theta'],bibeta_mmd2_optim_rqmc_n34_7['theta'],bibeta_mmd2_optim_rqmc_n34_8['theta'],bibeta_mmd2_optim_rqmc_n34_9['theta'],bibeta_mmd2_optim_rqmc_n34_10['theta']])
theta_w_rqmc_n34 = np.vstack([bibeta_w_optim_rqmc_n34_1['theta'],bibeta_w_optim_rqmc_n34_2['theta'],bibeta_w_optim_rqmc_n34_3['theta'],bibeta_w_optim_rqmc_n34_4['theta'],bibeta_w_optim_rqmc_n34_5['theta'],bibeta_w_optim_rqmc_n34_6['theta'],bibeta_w_optim_rqmc_n34_7['theta'],bibeta_w_optim_rqmc_n34_8['theta'],bibeta_w_optim_rqmc_n34_9['theta'],bibeta_w_optim_rqmc_n34_10['theta']])
theta_sw_rqmc_n34 = np.vstack([bibeta_sw_optim_rqmc_n34_1['theta'],bibeta_sw_optim_rqmc_n34_2['theta'],bibeta_sw_optim_rqmc_n34_3['theta'],bibeta_sw_optim_rqmc_n34_4['theta'],bibeta_sw_optim_rqmc_n34_5['theta'],bibeta_sw_optim_rqmc_n34_6['theta'],bibeta_sw_optim_rqmc_n34_7['theta'],bibeta_sw_optim_rqmc_n34_8['theta'],bibeta_sw_optim_rqmc_n34_9['theta'],bibeta_sw_optim_rqmc_n34_10['theta']])
theta_sink_rqmc_n34 = np.vstack([bibeta_sink_optim_rqmc_n34_1['theta'],bibeta_sink_optim_rqmc_n34_2['theta'],bibeta_sink_optim_rqmc_n34_3['theta'],bibeta_sink_optim_rqmc_n34_4['theta'],bibeta_sink_optim_rqmc_n34_5['theta'],bibeta_sink_optim_rqmc_n34_6['theta'],bibeta_sink_optim_rqmc_n34_7['theta'],bibeta_sink_optim_rqmc_n34_8['theta'],bibeta_sink_optim_rqmc_n34_9['theta'],bibeta_sink_optim_rqmc_n34_10['theta']])

# %%
# mc (n)
dist_mmd2_mc = np.squeeze(distance.cdist(theta_mmd2_mc,np.expand_dims(theta,0),'euclidean'))
dist_w_mc = np.squeeze(distance.cdist(theta_w_mc,np.expand_dims(theta,0),'euclidean'))
dist_sw_mc = np.squeeze(distance.cdist(theta_sw_mc,np.expand_dims(theta,0),'euclidean'))
dist_sink_mc = np.squeeze(distance.cdist(theta_sink_mc,np.expand_dims(theta,0),'euclidean'))

# rqmc (n)
dist_mmd2_rqmc = np.squeeze(distance.cdist(theta_mmd2_rqmc,np.expand_dims(theta,0),'euclidean'))
dist_w_rqmc = np.squeeze(distance.cdist(theta_w_rqmc,np.expand_dims(theta,0),'euclidean'))
dist_sw_rqmc = np.squeeze(distance.cdist(theta_sw_rqmc,np.expand_dims(theta,0),'euclidean'))
dist_sink_rqmc = np.squeeze(distance.cdist(theta_sink_rqmc,np.expand_dims(theta,0),'euclidean'))

# n^{1/2}
dist_mmd2_rqmc_n12 = np.squeeze(distance.cdist(theta_mmd2_rqmc_n12,np.expand_dims(theta,0),'euclidean'))
dist_w_rqmc_n12 = np.squeeze(distance.cdist(theta_w_rqmc_n12,np.expand_dims(theta,0),'euclidean'))
dist_sw_rqmc_n12 = np.squeeze(distance.cdist(theta_sw_rqmc_n12,np.expand_dims(theta,0),'euclidean'))
dist_sink_rqmc_n12 = np.squeeze(distance.cdist(theta_sink_rqmc_n12,np.expand_dims(theta,0),'euclidean'))

# n^{2/3}
dist_mmd2_rqmc_n23 = np.squeeze(distance.cdist(theta_mmd2_rqmc_n23,np.expand_dims(theta,0),'euclidean'))
dist_w_rqmc_n23 = np.squeeze(distance.cdist(theta_w_rqmc_n23,np.expand_dims(theta,0),'euclidean'))
dist_sw_rqmc_n23 = np.squeeze(distance.cdist(theta_sw_rqmc_n23,np.expand_dims(theta,0),'euclidean'))
dist_sink_rqmc_n23 = np.squeeze(distance.cdist(theta_sink_rqmc_n23,np.expand_dims(theta,0),'euclidean'))

# n^{3/4}
dist_mmd2_rqmc_n34 = np.squeeze(distance.cdist(theta_mmd2_rqmc_n34,np.expand_dims(theta,0),'euclidean'))
dist_w_rqmc_n34 = np.squeeze(distance.cdist(theta_w_rqmc_n34,np.expand_dims(theta,0),'euclidean'))
dist_sw_rqmc_n34 = np.squeeze(distance.cdist(theta_sw_rqmc_n34,np.expand_dims(theta,0),'euclidean'))
dist_sink_rqmc_n34 = np.squeeze(distance.cdist(theta_sink_rqmc_n34,np.expand_dims(theta,0),'euclidean'))

# %%
SMALL_SIZE = 30
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(32,8),sharey='row')
cmap = plt.get_cmap("tab10")
medianprops = dict(linewidth=2.5, color='firebrick')

bplot1 = ax1.boxplot([dist_mmd2_mc,dist_mmd2_rqmc,dist_mmd2_rqmc_n34,dist_mmd2_rqmc_n23,dist_mmd2_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot1 = ax1.boxplot([dist_mmd2_mc,dist_mmd2_rqmc,dist_mmd2_rqmc_n34,dist_mmd2_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax1.axhline(np.median(dist_mmd2_mc), linestyle='--', color='grey')
ax1.set_xticks([1,2,3,4,5])
#ax1.set_xticks([1,2,3,4])
ax1.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax1.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax1.set_ylabel(r'$||\theta^*-\hat{\theta}||_2$')
ax1.set_title(r'$D=\widehat{MMD}^2_V$')

bplot2 = ax2.boxplot([dist_w_mc,dist_w_rqmc,dist_w_rqmc_n34,dist_w_rqmc_n23,dist_w_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot2 = ax2.boxplot([dist_w_mc,dist_w_rqmc,dist_w_rqmc_n34,dist_w_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax2.axhline(np.median(dist_w_mc), linestyle='--', color='grey')
ax2.set_xticks([1,2,3,4,5])
#ax2.set_xticks([1,2,3,4])
ax2.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax2.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax2.set_title(r'$D=W_{c,p}$')

bplot3 = ax3.boxplot([dist_sw_mc,dist_sw_rqmc,dist_sw_rqmc_n34,dist_sw_rqmc_n23,dist_sw_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot3 = ax3.boxplot([dist_sw_mc,dist_sw_rqmc,dist_sw_rqmc_n34,dist_sw_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax3.axhline(np.median(dist_sw_mc), linestyle='--', color='grey')
ax3.set_xticks([1,2,3,4,5])
#ax3.set_xticks([1,2,3,4])
ax3.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax3.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax3.set_title(r'$D=SW_{c,p}$')

bplot4 = ax4.boxplot([dist_sink_mc,dist_sink_rqmc,dist_sink_rqmc_n34,dist_sink_rqmc_n23,dist_sink_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot4 = ax4.boxplot([dist_sink_mc,dist_sink_rqmc,dist_sink_rqmc_n34,dist_sink_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax4.axhline(np.median(dist_sink_mc), linestyle='--', color='grey')
ax4.set_xticks([1,2,3,4,5])
#ax4.set_xticks([1,2,3,4])
ax4.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax4.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax4.set_title(r'$D=S_{c,p,\lambda}$')

cmap = plt.get_cmap("tab10")
colors = [adjust_lightness(cmap(0),1.75), adjust_lightness(cmap(2),1.75), adjust_lightness(cmap(2),1.95), adjust_lightness(cmap(2),2.15), adjust_lightness(cmap(2),2.35)]
for bplot in (bplot1, bplot2, bplot3, bplot4):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

plt.subplots_adjust(wspace=0.15, hspace=0.05)

plt.savefig('bibeta_optim_l2norm.png',bbox_inches = 'tight', pad_inches = .1)

plt.show()

# %%
# mc (n)
mean_dist_mmd2_mc = np.mean(dist_mmd2_mc)
sd_dist_mmd2_mc = np.std(dist_mmd2_mc)
mean_dist_w_mc = np.mean(dist_w_mc)
sd_dist_w_mc = np.std(dist_w_mc)
mean_dist_sw_mc = np.mean(dist_sw_mc)
sd_dist_sw_mc = np.std(dist_sw_mc)
mean_dist_sink_mc = np.mean(dist_sink_mc)
sd_dist_sink_mc = np.std(dist_sink_mc)

# rqmc (n)
mean_dist_mmd2_rqmc = np.mean(dist_mmd2_rqmc)
sd_dist_mmd2_rqmc = np.std(dist_mmd2_rqmc)
mean_dist_w_rqmc = np.mean(dist_w_rqmc)
sd_dist_w_rqmc = np.std(dist_w_rqmc)
mean_dist_sw_rqmc = np.mean(dist_sw_rqmc)
sd_dist_sw_rqmc = np.std(dist_sw_rqmc)
mean_dist_sink_rqmc = np.mean(dist_sink_rqmc)
sd_dist_sink_rqmc = np.std(dist_sink_rqmc)

# n^{1/2}
mean_dist_mmd2_rqmc_n12 = np.mean(dist_mmd2_rqmc_n12)
sd_dist_mmd2_rqmc_n12 = np.std(dist_mmd2_rqmc_n12)
mean_dist_w_rqmc_n12 = np.mean(dist_w_rqmc_n12)
sd_dist_w_rqmc_n12 = np.std(dist_w_rqmc_n12)
mean_dist_sw_rqmc_n12 = np.mean(dist_sw_rqmc_n12)
sd_dist_sw_rqmc_n12 = np.std(dist_sw_rqmc_n12)
mean_dist_sink_rqmc_n12 = np.mean(dist_sink_rqmc_n12)
sd_dist_sink_rqmc_n12 = np.std(dist_sink_rqmc_n12)

# n^{2/3}
mean_dist_mmd2_rqmc_n23 = np.mean(dist_mmd2_rqmc_n23)
sd_dist_mmd2_rqmc_n23 = np.std(dist_mmd2_rqmc_n23)
mean_dist_w_rqmc_n23 = np.mean(dist_w_rqmc_n23)
sd_dist_w_rqmc_n23 = np.std(dist_w_rqmc_n23)
mean_dist_sw_rqmc_n23 = np.mean(dist_sw_rqmc_n23)
sd_dist_sw_rqmc_n23 = np.std(dist_sw_rqmc_n23)
mean_dist_sink_rqmc_n23 = np.mean(dist_sink_rqmc_n23)
sd_dist_sink_rqmc_n23 = np.std(dist_sink_rqmc_n23)

# n^{3/4}
mean_dist_mmd2_rqmc_n34 = np.mean(dist_mmd2_rqmc_n34)
sd_dist_mmd2_rqmc_n34 = np.std(dist_mmd2_rqmc_n34)
mean_dist_w_rqmc_n34 = np.mean(dist_w_rqmc_n34)
sd_dist_w_rqmc_n34 = np.std(dist_w_rqmc_n34)
mean_dist_sw_rqmc_n34 = np.mean(dist_sw_rqmc_n34)
sd_dist_sw_rqmc_n34 = np.std(dist_sw_rqmc_n34)
mean_dist_sink_rqmc_n34 = np.mean(dist_sink_rqmc_n34)
sd_dist_sink_rqmc_n34 = np.std(dist_sink_rqmc_n34)

# %%
print('\\begin{tabular}{| c | c | c | c | c | c | c | c | c| c | c |} ')
print('\hline')
print('& \multicolumn{2}{|c|}{MC} & \multicolumn{8}{|c|}{RQMC} \\\\')
print('\cline{2-11}')
print('\hline')
print('& \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n^{1/2}$}& \multicolumn{2}{|c|}{$n^{2/3}$}& \multicolumn{2}{|c|}{$n^{3/4}$} \\\\')
print('\cline{2-11}')
print('D & mean & sd & mean & sd & mean & sd & mean & sd & mean & sd \\\\')
print('\hline')
print('$\widehat{MMD}^2$ &', np.round(mean_dist_mmd2_mc,4),'&',np.round(sd_dist_mmd2_mc,4),'&', np.round(mean_dist_mmd2_rqmc,4),'&',np.round(sd_dist_mmd2_rqmc,4),'&',np.round(mean_dist_mmd2_rqmc_n12,4),'&',np.round(sd_dist_mmd2_rqmc_n12,4),'&', np.round(mean_dist_mmd2_rqmc_n23,4),'&',np.round(sd_dist_mmd2_rqmc_n23,4),'&', np.round(mean_dist_mmd2_rqmc_n34,4),'&',np.round(sd_dist_mmd2_rqmc_n34,4),'\\\\')
print('$W$ &', np.round(mean_dist_w_mc,4),'&',np.round(sd_dist_w_mc,4),'&', np.round(mean_dist_w_rqmc,4),'&',np.round(sd_dist_w_rqmc,4),'&',np.round(mean_dist_w_rqmc_n12,4),'&',np.round(sd_dist_w_rqmc_n12,4),'&', np.round(mean_dist_w_rqmc_n23,4),'&',np.round(sd_dist_w_rqmc_n23,4),'&', np.round(mean_dist_w_rqmc_n34,4),'&',np.round(sd_dist_w_rqmc_n34,4),'\\\\')
print('$SW$ &', np.round(mean_dist_sw_mc,4),'&',np.round(sd_dist_sw_mc,4),'&', np.round(mean_dist_sw_rqmc,4),'&',np.round(sd_dist_sw_rqmc,4),'&',np.round(mean_dist_sw_rqmc_n12,4),'&',np.round(sd_dist_sw_rqmc_n12,4),'&', np.round(mean_dist_sw_rqmc_n23,4),'&',np.round(sd_dist_sw_rqmc_n23,4),'&', np.round(mean_dist_sw_rqmc_n34,4),'&',np.round(sd_dist_sw_rqmc_n34,4),'\\\\')
print('$S$ &', np.round(mean_dist_sink_mc,4),'&',np.round(sd_dist_sink_mc,4),'&', np.round(mean_dist_sink_rqmc,4),'&',np.round(sd_dist_sink_rqmc,4),'&',np.round(mean_dist_sink_rqmc_n12,4),'&',np.round(sd_dist_sink_rqmc_n12,4),'&', np.round(mean_dist_sink_rqmc_n23,4),'&',np.round(sd_dist_sink_rqmc_n23,4),'&', np.round(mean_dist_sink_rqmc_n34,4),'&',np.round(sd_dist_sink_rqmc_n34,4),'\\\\')
print('\hline')
print('\end{tabular}')
# Out:
# \begin{tabular}{| c | c | c | c | c | c | c | c | c| c | c |}
# \hline
# & \multicolumn{2}{|c|}{MC} & \multicolumn{8}{|c|}{RQMC} \\
# \cline{2-11}
# \hline
# & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n$} & \multicolumn{2}{|c|}{$n^{1/2}$}& \multicolumn{2}{|c|}{$n^{2/3}$}& \multicolumn{2}{|c|}{$n^{3/4}$} \\
# \cline{2-11}
# D & mean & sd & mean & sd & mean & sd & mean & sd & mean & sd \\
# \hline
# $\widehat{MMD}^2$ & 0.2978 & 0.1632 & 0.2338 & 0.124 & 0.641 & 0.1989 & 0.4726 & 0.165 & 0.3698 & 0.1424 \\
# $W$ & 0.2769 & 0.1313 & 0.1223 & 0.0462 & 0.6274 & 0.1446 & 0.5047 & 0.2054 & 0.1793 & 0.0663 \\
# $SW$ & 0.3035 & 0.1048 & 0.0952 & 0.0261 & 0.619 & 0.243 & 0.3328 & 0.1029 & 0.2961 & 0.0833 \\
# $S$ & 0.2413 & 0.105 & 0.2367 & 0.1437 & 0.6574 & 0.3353 & 0.4221 & 0.1108 & 0.285 & 0.1126 \\
# \hline
# \end{tabular}

# %%
fig,((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(2,4,figsize=(32,16), sharey='row', sharex=True)
cmap = plt.get_cmap("tab10")
medianprops = dict(linewidth=2.5, color='firebrick')

bplot1 = ax1.boxplot([time_mmd2_mc,time_mmd2_rqmc,time_mmd2_rqmc_n34,time_mmd2_rqmc_n23,time_mmd2_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot1 = ax1.boxplot([time_mmd2_mc,time_mmd2_rqmc,time_mmd2_rqmc_n34,time_mmd2_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax1.axhline(np.median(time_mmd2_mc), linestyle='--', color='grey')
ax1.set_xticks([1,2,3,4,5])
#ax1.set_xticks([1,2,3,4])
ax1.set_ylabel('computation time [hours]')
ax1.set_title(r'$D=\widehat{MMD}^2_V$', pad=20)

bplot2 = ax2.boxplot([time_w_mc,time_w_rqmc,time_w_rqmc_n34,time_w_rqmc_n23,time_w_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot2 = ax2.boxplot([time_w_mc,time_w_rqmc,time_w_rqmc_n34,time_w_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax2.axhline(np.median(time_w_mc), linestyle='--', color='grey')
ax2.set_xticks([1,2,3,4,5])
#ax2.set_xticks([1,2,3,4])
ax2.set_title(r'$D=W_{c,p}$', pad=20)

bplot3 = ax3.boxplot([time_sw_mc,time_sw_rqmc,time_sw_rqmc_n34,time_sw_rqmc_n23,time_sw_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot3 = ax3.boxplot([time_sw_mc,time_sw_rqmc,time_sw_rqmc_n34,time_sw_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax3.axhline(np.median(time_sw_mc), linestyle='--', color='grey')
ax3.set_xticks([1,2,3,4,5])
#ax3.set_xticks([1,2,3,4])
ax3.set_title(r'$D=SW_{c,p}$', pad=20)

bplot4 = ax4.boxplot([time_sink_mc,time_sink_rqmc,time_sink_rqmc_n34,time_sink_rqmc_n23,time_sink_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot4 = ax4.boxplot([time_sink_mc,time_sink_rqmc,time_sink_rqmc_n34,time_sink_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax4.axhline(np.median(time_sink_mc), linestyle='--', color='grey')
ax4.set_xticks([1,2,3,4,5])
#ax4.set_xticks([1,2,3,4])
ax4.set_title(r'$D=S_{c,p,\lambda}$', pad=20)

bplot5 = ax5.boxplot([dist_mmd2_mc,dist_mmd2_rqmc,dist_mmd2_rqmc_n34,dist_mmd2_rqmc_n23,dist_mmd2_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot = ax5.boxplot([dist_mmd2_mc,dist_mmd2_rqmc,dist_mmd2_rqmc_n34,dist_mmd2_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax5.axhline(np.median(dist_mmd2_mc), linestyle='--', color='grey')
ax5.set_xticks([1,2,3,4,5])
#ax5.set_xticks([1,2,3,4])
ax5.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax5.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])
ax5.set_ylabel(r'$||\theta^*-\hat{\theta}||_2$')

bplot6 = ax6.boxplot([dist_w_mc,dist_w_rqmc,dist_w_rqmc_n34,dist_w_rqmc_n23,dist_w_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot6 = ax6.boxplot([dist_w_mc,dist_w_rqmc,dist_w_rqmc_n34,dist_w_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax6.axhline(np.median(dist_w_mc), linestyle='--', color='grey')
ax6.set_xticks([1,2,3,4,5])
#ax6.set_xticks([1,2,3,4])
ax6.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax6.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])

bplot7 = ax7.boxplot([dist_sw_mc,dist_sw_rqmc,dist_sw_rqmc_n34,dist_sw_rqmc_n23,dist_sw_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot7 = ax7.boxplot([dist_sw_mc,dist_sw_rqmc,dist_sw_rqmc_n34,dist_sw_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax7.axhline(np.median(dist_sw_mc), linestyle='--', color='grey')
ax7.set_xticks([1,2,3,4,5])
#ax7.set_xticks([1,2,3,4])
ax7.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax7.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])

bplot8 = ax8.boxplot([dist_sink_mc,dist_sink_rqmc,dist_sink_rqmc_n34,dist_sink_rqmc_n23,dist_sink_rqmc_n12],patch_artist=True,medianprops=medianprops)
#bplot8 = ax8.boxplot([dist_sink_mc,dist_sink_rqmc,dist_sink_rqmc_n34,dist_sink_rqmc_n23],patch_artist=True,medianprops=medianprops)
ax8.axhline(np.median(dist_sink_mc), linestyle='--', color='grey')
ax8.set_xticks([1,2,3,4,5])
#ax8.set_xticks([1,2,3,4])
ax8.set_xticklabels([r'$MC\,(n)$',r'$RQMC\,(n)$',r'$RQMC\,(n^{3/4})$',r'$RQMC\,(n^{2/3})$',r'$RQMC\,(n^{1/2})$'],rotation=45)
#ax8.set_xticklabels(['MC','RQMC',r'$n^{3/4}$',r'$n^{2/3}$'])

cmap = plt.get_cmap("tab10")
colors = [adjust_lightness(cmap(0),1.75), adjust_lightness(cmap(2),1.75), adjust_lightness(cmap(2),1.95), adjust_lightness(cmap(2),2.15), adjust_lightness(cmap(2),2.35)]
for bplot in (bplot1, bplot2, bplot3, bplot4, bplot5, bplot6, bplot7, bplot8):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)

plt.subplots_adjust(wspace=0.15, hspace=0.1)

plt.savefig('bibeta_optim_time+l2norm.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %% [markdown]
# ## Multivariate g-and-k distribution

# %% [markdown]
# Plot the MMD$^2$ loss of the g-and-k distribution for $d=1$ without subsampling:

# %%
SMALL_SIZE = 32
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
plt.figure(figsize=(16,7))
cmap = plt.get_cmap("tab10")

plt.plot(np.abs(gank_mmd2_optim_kgaussian['loss_mc']), color=cmap(0),label='MC')
plt.plot(np.abs(gank_mmd2_optim_kgaussian['loss_rqmc']), color=cmap(2),label='RQMC')
plt.yscale('log', basey=10)
plt.ylabel(r'$|\widehat{MMD}^2_V(P^n,Q^m)|$')
plt.legend(loc='upper right')
plt.xlabel('Descent steps')

plt.savefig('gandk_mmd2_loss.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %% [markdown]
# Plot error of parameter estimates for $d=1$ without subsampling:

# %%
theta = np.array([3,1,1,-np.log(2)])
max_it = 10000

# %%
SMALL_SIZE = 32
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(32,8),sharey='row')
cmap = plt.get_cmap("tab10")

ax1.plot(range(max_it+1),np.abs(theta[0]-gank_mmd2_optim_kgaussian['theta_mc'][:,0]), color=cmap(0), label='MC')
ax1.plot(range(max_it+1),np.abs(theta[0]-gank_mmd2_optim_kgaussian['theta_rqmc'][:,0]), color=cmap(2), label='RQMC')
ax1.set_yscale('log', basey=10)
ax1.set_xlabel('Descent steps')
ax1.set_ylabel(r'$|\theta_i^*-\hat{\theta}_i|$')
ax1.set_title(r'$\theta^*_{1}=$'+str(theta[0].astype(int)))

ax2.plot(range(max_it+1),np.abs(theta[1]-gank_mmd2_optim_kgaussian['theta_mc'][:,1]), color=cmap(0), label='MC')
ax2.plot(range(max_it+1),np.abs(theta[1]-gank_mmd2_optim_kgaussian['theta_rqmc'][:,1]), color=cmap(2), label='RQMC')
ax2.set_yscale('log', basey=10)
ax2.set_xlabel('Descent steps')
ax2.set_title(r'$\theta^*_{2}=$'+str(theta[1].astype(int)))

ax3.plot(range(max_it+1),np.abs(theta[2]-gank_mmd2_optim_kgaussian['theta_mc'][:,2]), color=cmap(0), label='MC')
ax3.plot(range(max_it+1),np.abs(theta[2]-gank_mmd2_optim_kgaussian['theta_rqmc'][:,2]), color=cmap(2), label='RQMC')
ax3.set_yscale('log', basey=10)
ax3.set_xlabel('Descent steps')
ax3.set_title(r'$\theta^*_{3}=$'+str(theta[2].astype(int)))

ax4.plot(range(max_it+1),np.abs(theta[3]-gank_mmd2_optim_kgaussian['theta_mc'][:,3]), color=cmap(0), label='MC')
ax4.plot(range(max_it+1),np.abs(theta[3]-gank_mmd2_optim_kgaussian['theta_rqmc'][:,3]), color=cmap(2), label='RQMC')
ax4.set_yscale('log', basey=10)
ax4.set_xlabel('Descent steps')
#ax4.set_title(r'$\theta^*_{4}=$'+str(round(theta[3],4)))
ax4.set_title(r'$\theta^*_{4}=-\log(2)$')
ax4.legend(loc='lower right')

plt.subplots_adjust(wspace=0.05, hspace=0.05)

plt.savefig('gandk_mmd2_estimates.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %%
dist_mc = distance.cdist(gank_mmd2_optim_kgaussian['theta_mc'],np.expand_dims(theta,0),'euclidean')
dist_rqmc = distance.cdist(gank_mmd2_optim_kgaussian['theta_rqmc'],np.expand_dims(theta,0),'euclidean')

plt.figure(figsize=(16,7))
cmap = plt.get_cmap("tab10")

plt.plot(dist_mc, color=cmap(0), label='MC')
plt.plot(dist_rqmc, color=cmap(2), label='RQMC')
plt.yscale('log', basey=10)
plt.ylabel(r'$||\hat{\theta}-\theta^*||_2$')
plt.xlabel('Descent steps')
plt.title(r'$\theta^*=($'+str(theta[0].astype(int))+', '+str(theta[1].astype(int))+', '+str(theta[2].astype(int))+r'$,-\log(2))$')
plt.legend(loc='upper right')

plt.savefig('gandk_mmd2_estimates_l2norm.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %% [markdown]
# Convergence of MMD$^2$, sliced Wasserstein distance and Sinkhorn divergence with varying $d$ for the multivariate g-and-k distribution:

# %%
n = [ 2**j for j in range(3,15) ]

# %%
SMALL_SIZE = 28
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(28,8))
cmap = plt.get_cmap("tab10")

# MMD^2(P^n,Q^m) against n
ax1.plot(n[:-1], mvgandk_mmd2_n_d1['mmd_rqmc'][:-1], linewidth=2, color=cmap(0), label='d=1')
ax1.plot(n[:-1], mvgandk_mmd2_n_d1['mmd_mc'][:-1],'--', linewidth=2, color=cmap(0))
ax1.plot(n[:-1], mvgandk_mmd2_n_d5['mmd_rqmc'][:-1], linewidth=2, color=cmap(1), label='d=5')
ax1.plot(n[:-1], mvgandk_mmd2_n_d5['mmd_mc'][:-1],'--', linewidth=2, color=cmap(1))
ax1.plot(n[:-1], mvgandk_mmd2_n_d10['mmd_rqmc'][:-1], linewidth=2, color=cmap(2), label='d=10')
ax1.plot(n[:-1], mvgandk_mmd2_n_d10['mmd_mc'][:-1],'--', linewidth=2, color=cmap(2))
ax1.plot(n[:-1], mvgandk_mmd2_n_d25['mmd_rqmc'][:-1], linewidth=2, color=cmap(3), label='d=25')
ax1.plot(n[:-1], mvgandk_mmd2_n_d25['mmd_mc'][:-1],'--', linewidth=2, color=cmap(3))
ax1.plot(n[:-1], mvgandk_mmd2_n_d50['mmd_rqmc'][:-1], linewidth=2, color=cmap(4), label='d=50')
ax1.plot(n[:-1], mvgandk_mmd2_n_d50['mmd_mc'][:-1],'--', linewidth=2, color=cmap(4))
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d1['mmd_mc'][:-1], yerr=[mvgandk_mmd2_n_d1['mmd_mc'][:-1]-mvgandk_mmd2_n_d1['mmd_min_mc'][:-1],mvgandk_mmd2_n_d1['mmd_max_mc'][:-1]-mvgandk_mmd2_n_d1['mmd_mc'][:-1]], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d1['mmd_rqmc'][:-1], yerr=[mvgandk_mmd2_n_d1['mmd_rqmc'][:-1]-mvgandk_mmd2_n_d1['mmd_min_rqmc'][:-1],mvgandk_mmd2_n_d1['mmd_max_rqmc'][:-1]-mvgandk_mmd2_n_d1['mmd_rqmc'][:-1]], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d5['mmd_mc'][:-1], yerr=[mvgandk_mmd2_n_d5['mmd_mc'][:-1]-mvgandk_mmd2_n_d5['mmd_min_mc'][:-1],mvgandk_mmd2_n_d5['mmd_max_mc'][:-1]-mvgandk_mmd2_n_d5['mmd_mc'][:-1]], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d5['mmd_rqmc'][:-1], yerr=[mvgandk_mmd2_n_d5['mmd_rqmc'][:-1]-mvgandk_mmd2_n_d5['mmd_min_rqmc'][:-1],mvgandk_mmd2_n_d5['mmd_max_rqmc'][:-1]-mvgandk_mmd2_n_d5['mmd_rqmc'][:-1]], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d10['mmd_rqmc'][:-1], yerr=[mvgandk_mmd2_n_d10['mmd_rqmc'][:-1]-mvgandk_mmd2_n_d10['mmd_min_rqmc'][:-1],mvgandk_mmd2_n_d10['mmd_max_rqmc'][:-1]-mvgandk_mmd2_n_d10['mmd_rqmc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d10['mmd_mc'][:-1], yerr=[mvgandk_mmd2_n_d10['mmd_mc'][:-1]-mvgandk_mmd2_n_d10['mmd_min_mc'][:-1],mvgandk_mmd2_n_d10['mmd_max_mc'][:-1]-mvgandk_mmd2_n_d10['mmd_mc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d25['mmd_rqmc'][:-1], yerr=[mvgandk_mmd2_n_d25['mmd_rqmc'][:-1]-mvgandk_mmd2_n_d25['mmd_min_rqmc'][:-1],mvgandk_mmd2_n_d25['mmd_max_rqmc'][:-1]-mvgandk_mmd2_n_d25['mmd_rqmc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d25['mmd_mc'][:-1], yerr=[mvgandk_mmd2_n_d25['mmd_mc'][:-1]-mvgandk_mmd2_n_d25['mmd_min_mc'][:-1],mvgandk_mmd2_n_d25['mmd_max_mc'][:-1]-mvgandk_mmd2_n_d25['mmd_mc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d50['mmd_rqmc'][:-1], yerr=[mvgandk_mmd2_n_d50['mmd_rqmc'][:-1]-mvgandk_mmd2_n_d50['mmd_min_rqmc'][:-1],mvgandk_mmd2_n_d50['mmd_max_rqmc'][:-1]-mvgandk_mmd2_n_d50['mmd_rqmc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_mmd2_n_d50['mmd_mc'][:-1], yerr=[mvgandk_mmd2_n_d50['mmd_mc'][:-1]-mvgandk_mmd2_n_d50['mmd_min_mc'][:-1],mvgandk_mmd2_n_d50['mmd_max_mc'][:-1]-mvgandk_mmd2_n_d50['mmd_mc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.set_xscale('log', basex=2)
ax1.set_yscale('log', basey=10)
ax1.set_xlabel('n=m')
ax1.set_ylabel(r'$|D(P^n,Q^m)|$')
ax1.set_title(r'$D = \widehat{MMD}^2_V$')
ax1.legend(loc= 'lower left',ncol=2,handlelength=1.5,labelspacing=0.3,handletextpad=0.3,columnspacing=1)

# SW(P^n,Q^m) against n
ax2.plot(n[:-1], mvgandk_sw_n_d1['w_rqmc'][:-1], linewidth=2, color=cmap(0), label='d=1')
ax2.plot(n[:-1], mvgandk_sw_n_d1['w_mc'][:-1],'--', linewidth=2, color=cmap(0))
ax2.plot(n[:-1], mvgandk_sw_n_d5['w_rqmc'][:-1], linewidth=2, color=cmap(1), label='d=5')
ax2.plot(n[:-1], mvgandk_sw_n_d5['w_mc'][:-1],'--', linewidth=2, color=cmap(1))
ax2.plot(n[:-1], mvgandk_sw_n_d10['w_rqmc'][:-1], linewidth=2, color=cmap(2), label='d=10')
ax2.plot(n[:-1], mvgandk_sw_n_d10['w_mc'][:-1],'--', linewidth=2, color=cmap(2))
ax2.plot(n[:-1], mvgandk_sw_n_d25['w_rqmc'][:-1], linewidth=2, color=cmap(3), label='d=25')
ax2.plot(n[:-1], mvgandk_sw_n_d25['w_mc'][:-1],'--', linewidth=2, color=cmap(3))
ax2.plot(n[:-1], mvgandk_sw_n_d50['w_rqmc'][:-1], linewidth=2, color=cmap(4), label='d=50')
ax2.plot(n[:-1], mvgandk_sw_n_d50['w_mc'][:-1],'--', linewidth=2, color=cmap(4))
ax2.errorbar(n[:-1], mvgandk_sw_n_d1['w_mc'][:-1], yerr=[mvgandk_sw_n_d1['w_mc'][:-1]-mvgandk_sw_n_d1['w_min_mc'][:-1],mvgandk_sw_n_d1['w_max_mc'][:-1]-mvgandk_sw_n_d1['w_mc'][:-1]], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d1['w_rqmc'][:-1], yerr=[mvgandk_sw_n_d1['w_rqmc'][:-1]-mvgandk_sw_n_d1['w_min_rqmc'][:-1],mvgandk_sw_n_d1['w_max_rqmc'][:-1]-mvgandk_sw_n_d1['w_rqmc'][:-1]], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d5['w_mc'][:-1], yerr=[mvgandk_sw_n_d5['w_mc'][:-1]-mvgandk_sw_n_d5['w_min_mc'][:-1],mvgandk_sw_n_d5['w_max_mc'][:-1]-mvgandk_sw_n_d5['w_mc'][:-1]], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d5['w_rqmc'][:-1], yerr=[mvgandk_sw_n_d5['w_rqmc'][:-1]-mvgandk_sw_n_d5['w_min_rqmc'][:-1],mvgandk_sw_n_d5['w_max_rqmc'][:-1]-mvgandk_sw_n_d5['w_rqmc'][:-1]], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d10['w_rqmc'][:-1], yerr=[mvgandk_sw_n_d10['w_rqmc'][:-1]-mvgandk_sw_n_d10['w_min_rqmc'][:-1],mvgandk_sw_n_d10['w_max_rqmc'][:-1]-mvgandk_sw_n_d10['w_rqmc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d10['w_mc'][:-1], yerr=[mvgandk_sw_n_d10['w_mc'][:-1]-mvgandk_sw_n_d10['w_min_mc'][:-1],mvgandk_sw_n_d10['w_max_mc'][:-1]-mvgandk_sw_n_d10['w_mc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d25['w_rqmc'][:-1], yerr=[mvgandk_sw_n_d25['w_rqmc'][:-1]-mvgandk_sw_n_d25['w_min_rqmc'][:-1],mvgandk_sw_n_d25['w_max_rqmc'][:-1]-mvgandk_sw_n_d25['w_rqmc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d25['w_mc'][:-1], yerr=[mvgandk_sw_n_d25['w_mc'][:-1]-mvgandk_sw_n_d25['w_min_mc'][:-1],mvgandk_sw_n_d25['w_max_mc'][:-1]-mvgandk_sw_n_d25['w_mc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d50['w_rqmc'][:-1], yerr=[mvgandk_sw_n_d50['w_rqmc'][:-1]-mvgandk_sw_n_d50['w_min_rqmc'][:-1],mvgandk_sw_n_d50['w_max_rqmc'][:-1]-mvgandk_sw_n_d50['w_rqmc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax2.errorbar(n[:-1], mvgandk_sw_n_d50['w_mc'][:-1], yerr=[mvgandk_sw_n_d50['w_mc'][:-1]-mvgandk_sw_n_d50['w_min_mc'][:-1],mvgandk_sw_n_d50['w_max_mc'][:-1]-mvgandk_sw_n_d50['w_mc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax2.set_xscale('log', basex=2)
ax2.set_yscale('log', basey=10)
ax2.set_xlabel('n=m')
#ax2.set_ylabel(r'$|SW_{c,p}(P^n,Q^m)|$')
ax2.set_title(r'$D = SW_{c,p}$')

# S(P^n,Q^m) against n
ax3.plot(n[:-1], mvgandk_sink_n_d1['sink_rqmc'], linewidth=2, color=cmap(0), label='d=1')
ax3.plot(n[:-1], mvgandk_sink_n_d1['sink_mc'],'--', linewidth=2, color=cmap(0))
ax3.plot(n[:-1], mvgandk_sink_n_d5['sink_rqmc'], linewidth=2, color=cmap(1), label='d=5')
ax3.plot(n[:-1], mvgandk_sink_n_d5['sink_mc'],'--', linewidth=2, color=cmap(1))
ax3.plot(n[:-1], mvgandk_sink_n_d10['sink_rqmc'][:-1], linewidth=2, color=cmap(2), label='d=10')
ax3.plot(n[:-1], mvgandk_sink_n_d10['sink_mc'][:-1],'--', linewidth=2, color=cmap(2))
ax3.plot(n[:-1], mvgandk_sink_n_d25['sink_rqmc'][:-1], linewidth=2, color=cmap(3), label='d=25')
ax3.plot(n[:-1], mvgandk_sink_n_d25['sink_mc'][:-1],'--', linewidth=2, color=cmap(3))
ax3.plot(n[:-1], mvgandk_sink_n_d50['sink_rqmc'][:-1], linewidth=2, color=cmap(4), label='d=50')
ax3.plot(n[:-1], mvgandk_sink_n_d50['sink_mc'][:-1],'--', linewidth=2, color=cmap(4))
ax3.errorbar(n[:-1], mvgandk_sink_n_d1['sink_mc'], yerr=[mvgandk_sink_n_d1['sink_mc']-mvgandk_sink_n_d1['sink_min_mc'],mvgandk_sink_n_d1['sink_max_mc']-mvgandk_sink_n_d1['sink_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d1['sink_rqmc'], yerr=[mvgandk_sink_n_d1['sink_rqmc']-mvgandk_sink_n_d1['sink_min_rqmc'],mvgandk_sink_n_d1['sink_max_rqmc']-mvgandk_sink_n_d1['sink_rqmc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d5['sink_mc'], yerr=[mvgandk_sink_n_d5['sink_mc']-mvgandk_sink_n_d5['sink_min_mc'],mvgandk_sink_n_d5['sink_max_mc']-mvgandk_sink_n_d5['sink_mc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d5['sink_rqmc'], yerr=[mvgandk_sink_n_d5['sink_rqmc']-mvgandk_sink_n_d5['sink_min_rqmc'],mvgandk_sink_n_d5['sink_max_rqmc']-mvgandk_sink_n_d5['sink_rqmc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d10['sink_rqmc'][:-1], yerr=[mvgandk_sink_n_d10['sink_rqmc'][:-1]-mvgandk_sink_n_d10['sink_min_rqmc'][:-1],mvgandk_sink_n_d10['sink_max_rqmc'][:-1]-mvgandk_sink_n_d10['sink_rqmc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d10['sink_mc'][:-1], yerr=[mvgandk_sink_n_d10['sink_mc'][:-1]-mvgandk_sink_n_d10['sink_min_mc'][:-1],mvgandk_sink_n_d10['sink_max_mc'][:-1]-mvgandk_sink_n_d10['sink_mc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d25['sink_rqmc'][:-1], yerr=[mvgandk_sink_n_d25['sink_rqmc'][:-1]-mvgandk_sink_n_d25['sink_min_rqmc'][:-1],mvgandk_sink_n_d25['sink_max_rqmc'][:-1]-mvgandk_sink_n_d25['sink_rqmc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d25['sink_mc'][:-1], yerr=[mvgandk_sink_n_d25['sink_mc'][:-1]-mvgandk_sink_n_d25['sink_min_mc'][:-1],mvgandk_sink_n_d25['sink_max_mc'][:-1]-mvgandk_sink_n_d25['sink_mc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d50['sink_rqmc'][:-1], yerr=[mvgandk_sink_n_d50['sink_rqmc'][:-1]-mvgandk_sink_n_d50['sink_min_rqmc'][:-1],mvgandk_sink_n_d50['sink_max_rqmc'][:-1]-mvgandk_sink_n_d50['sink_rqmc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax3.errorbar(n[:-1], mvgandk_sink_n_d50['sink_mc'][:-1], yerr=[mvgandk_sink_n_d50['sink_mc'][:-1]-mvgandk_sink_n_d50['sink_min_mc'][:-1],mvgandk_sink_n_d50['sink_max_mc'][:-1]-mvgandk_sink_n_d50['sink_mc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax3.set_xscale('log', basex=2)
ax3.set_yscale('log', basey=10)
ax3.set_ylim(1e-8,500)
ax3.set_xlabel('n=m')
#ax3.set_ylabel(r'$|S_{c,p,\lambda}(P^n,Q^m)|$')
ax3.set_title(r'$D = S_{c,p,\lambda}$')

plt.subplots_adjust(wspace=0.2, hspace=0.05)

plt.savefig('mvgandk_convergence.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# Convergence of the MMD$^2$ for the multivariate g-and-k distribution:

# %%
n = [ 2**j for j in range(3,15) ]
d = [1,5,10,15,20,25,50,75,100,150,200,300]

# %%
SMALL_SIZE = 28
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(18,8),sharey='row')
cmap = plt.get_cmap("tab10")

# MMD^2(P^n,Q^m) against n
ax1.plot(n, mvgandk_mmd2_n_d1['mmd_rqmc'], linewidth=2, color=cmap(0), label='d=1')
ax1.plot(n, mvgandk_mmd2_n_d1['mmd_mc'],'--', linewidth=2, color=cmap(0))
ax1.plot(n, mvgandk_mmd2_n_d5['mmd_rqmc'], linewidth=2, color=cmap(1), label='d=5')
ax1.plot(n, mvgandk_mmd2_n_d5['mmd_mc'],'--', linewidth=2, color=cmap(1))
ax1.plot(n, mvgandk_mmd2_n_d10['mmd_rqmc'], linewidth=2, color=cmap(2), label='d=10')
ax1.plot(n, mvgandk_mmd2_n_d10['mmd_mc'],'--', linewidth=2, color=cmap(2))
ax1.plot(n, mvgandk_mmd2_n_d25['mmd_rqmc'], linewidth=2, color=cmap(3), label='d=25')
ax1.plot(n, mvgandk_mmd2_n_d25['mmd_mc'],'--', linewidth=2, color=cmap(3))
ax1.plot(n, mvgandk_mmd2_n_d50['mmd_rqmc'], linewidth=2, color=cmap(4), label='d=50')
ax1.plot(n, mvgandk_mmd2_n_d50['mmd_mc'],'--', linewidth=2, color=cmap(4))
ax1.errorbar(n, mvgandk_mmd2_n_d1['mmd_mc'], yerr=[mvgandk_mmd2_n_d1['mmd_mc']-mvgandk_mmd2_n_d1['mmd_min_mc'],mvgandk_mmd2_n_d1['mmd_max_mc']-mvgandk_mmd2_n_d1['mmd_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d1['mmd_rqmc'], yerr=[mvgandk_mmd2_n_d1['mmd_rqmc']-mvgandk_mmd2_n_d1['mmd_min_rqmc'],mvgandk_mmd2_n_d1['mmd_max_rqmc']-mvgandk_mmd2_n_d1['mmd_rqmc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d5['mmd_mc'], yerr=[mvgandk_mmd2_n_d5['mmd_mc']-mvgandk_mmd2_n_d5['mmd_min_mc'],mvgandk_mmd2_n_d5['mmd_max_mc']-mvgandk_mmd2_n_d5['mmd_mc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d5['mmd_rqmc'], yerr=[mvgandk_mmd2_n_d5['mmd_rqmc']-mvgandk_mmd2_n_d5['mmd_min_rqmc'],mvgandk_mmd2_n_d5['mmd_max_rqmc']-mvgandk_mmd2_n_d5['mmd_rqmc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d10['mmd_rqmc'], yerr=[mvgandk_mmd2_n_d10['mmd_rqmc']-mvgandk_mmd2_n_d10['mmd_min_rqmc'],mvgandk_mmd2_n_d10['mmd_max_rqmc']-mvgandk_mmd2_n_d10['mmd_rqmc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d10['mmd_mc'], yerr=[mvgandk_mmd2_n_d10['mmd_mc']-mvgandk_mmd2_n_d10['mmd_min_mc'],mvgandk_mmd2_n_d10['mmd_max_mc']-mvgandk_mmd2_n_d10['mmd_mc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d25['mmd_rqmc'], yerr=[mvgandk_mmd2_n_d25['mmd_rqmc']-mvgandk_mmd2_n_d25['mmd_min_rqmc'],mvgandk_mmd2_n_d25['mmd_max_rqmc']-mvgandk_mmd2_n_d25['mmd_rqmc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d25['mmd_mc'], yerr=[mvgandk_mmd2_n_d25['mmd_mc']-mvgandk_mmd2_n_d25['mmd_min_mc'],mvgandk_mmd2_n_d25['mmd_max_mc']-mvgandk_mmd2_n_d25['mmd_mc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d50['mmd_rqmc'], yerr=[mvgandk_mmd2_n_d50['mmd_rqmc']-mvgandk_mmd2_n_d50['mmd_min_rqmc'],mvgandk_mmd2_n_d50['mmd_max_rqmc']-mvgandk_mmd2_n_d50['mmd_rqmc']], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_mmd2_n_d50['mmd_mc'], yerr=[mvgandk_mmd2_n_d50['mmd_mc']-mvgandk_mmd2_n_d50['mmd_min_mc'],mvgandk_mmd2_n_d50['mmd_max_mc']-mvgandk_mmd2_n_d50['mmd_mc']], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.set_xscale('log', basex=2)
ax1.set_yscale('log', basey=10)
ax1.set_xlabel('n=m')
ax1.set_ylabel(r'$|\widehat{MMD}^2_V(P^n,Q^m)|$')
ax1.set_title('varying n=m')
ax1.legend(loc= 'lower left',ncol=2,handlelength=1.5,labelspacing=0.3,handletextpad=0.3,columnspacing=1)

# MMD^2(P^n,Q^m) against d
ax2.plot(d, mvgandk_mmd2_d['mmd_mc'], linewidth=2, color=cmap(0),label='MC')
ax2.plot(d, mvgandk_mmd2_d['mmd_rqmc'], linewidth=2, color=cmap(2),label='RQMC')
ax2.errorbar(d, mvgandk_mmd2_d['mmd_mc'], yerr=[mvgandk_mmd2_d['mmd_mc']-mvgandk_mmd2_d['mmd_min_mc'],mvgandk_mmd2_d['mmd_max_mc']-mvgandk_mmd2_d['mmd_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2.errorbar(d, mvgandk_mmd2_d['mmd_rqmc'], yerr=[mvgandk_mmd2_d['mmd_rqmc']-mvgandk_mmd2_d['mmd_min_rqmc'],mvgandk_mmd2_d['mmd_max_rqmc']-mvgandk_mmd2_d['mmd_rqmc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2.set_xlabel('d')
ax2.set_title('n=m='+r'$2^{13}$'+', varying d')
ax2.set_xticks(np.hstack((np.ones(1),np.arange(100,400,100)))) 
ax2.set_xticklabels(np.hstack((np.ones(1),np.arange(100,400,100))).astype(int))
ax2.legend(loc= 'lower right')

plt.subplots_adjust(wspace=0.05, hspace=0.05)

plt.savefig('mvgandk_mmd2_convergence.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %%
from sklearn import linear_model

# %%
lm1_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d5['mmd_mc'])).reshape(-1,1))
lm1_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d5['mmd_rqmc'])).reshape(-1,1))
lm2_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d10['mmd_mc'])).reshape(-1,1))
lm2_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d10['mmd_rqmc'])).reshape(-1,1))
lm3_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d25['mmd_mc'])).reshape(-1,1))
lm3_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d25['mmd_rqmc'])).reshape(-1,1))
lm4_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d50['mmd_mc'])).reshape(-1,1))
lm4_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_mmd2_n_d50['mmd_rqmc'])).reshape(-1,1))

# %%
print('\\begin{tabular}{ c | c | c } ')
print('& MC & RQMC \\\\')
print('\hline')
print('$d=5$ &', np.round(np.squeeze(lm1_mc.coef_),4),'&',np.round(np.squeeze(lm1_rqmc.coef_),4),'\\\\')
print('$d=10$ &', np.round(np.squeeze(lm2_mc.coef_),4),'&',np.round(np.squeeze(lm2_rqmc.coef_),4),'\\\\')
print('$d=25$ &', np.round(np.squeeze(lm3_mc.coef_),4),'&',np.round(np.squeeze(lm3_rqmc.coef_),4),'\\\\')
print('$d=50$ &', np.round(np.squeeze(lm4_mc.coef_),4),'&',np.round(np.squeeze(lm4_rqmc.coef_),4),'\\\\')
print('\end{tabular}')
# Out:
# \begin{tabular}{ c | c | c }
# & MC & RQMC \\
# \hline
# $d=5$ & -0.5032 & -0.7315 \\
# $d=10$ & -0.4993 & -0.6518 \\
# $d=25$ & -0.5021 & -0.5829 \\
# $d=50$ & -0.5031 & -0.5387 \\
# \end{tabular}

# %% [markdown]
# Convergence of the sliced Wasserstein distance for the multivariate g-and-k distribution:

# %%
n = [ 2**j for j in range(3,15) ]
d = [1,5,10,15,20,25,50,75,100,150,200,300]

# %%
SMALL_SIZE = 28
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(18,8),sharey='row')
cmap = plt.get_cmap("tab10")

# SW(P^n,Q^m) against n
ax1.plot(n, mvgandk_sw_n_d1['w_rqmc'], linewidth=2, color=cmap(0), label='d=1')
ax1.plot(n, mvgandk_sw_n_d1['w_mc'],'--', linewidth=2, color=cmap(0))
ax1.plot(n, mvgandk_sw_n_d5['w_rqmc'], linewidth=2, color=cmap(1), label='d=5')
ax1.plot(n, mvgandk_sw_n_d5['w_mc'],'--', linewidth=2, color=cmap(1))
ax1.plot(n, mvgandk_sw_n_d10['w_rqmc'], linewidth=2, color=cmap(2), label='d=10')
ax1.plot(n, mvgandk_sw_n_d10['w_mc'],'--', linewidth=2, color=cmap(2))
ax1.plot(n, mvgandk_sw_n_d25['w_rqmc'], linewidth=2, color=cmap(3), label='d=25')
ax1.plot(n, mvgandk_sw_n_d25['w_mc'],'--', linewidth=2, color=cmap(3))
ax1.plot(n, mvgandk_sw_n_d50['w_rqmc'], linewidth=2, color=cmap(4), label='d=50')
ax1.plot(n, mvgandk_sw_n_d50['w_mc'],'--', linewidth=2, color=cmap(4))
ax1.errorbar(n, mvgandk_sw_n_d1['w_mc'], yerr=[mvgandk_sw_n_d1['w_mc']-mvgandk_sw_n_d1['w_min_mc'],mvgandk_sw_n_d1['w_max_mc']-mvgandk_sw_n_d1['w_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d1['w_rqmc'], yerr=[mvgandk_sw_n_d1['w_rqmc']-mvgandk_sw_n_d1['w_min_rqmc'],mvgandk_sw_n_d1['w_max_rqmc']-mvgandk_sw_n_d1['w_rqmc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d5['w_mc'], yerr=[mvgandk_sw_n_d5['w_mc']-mvgandk_sw_n_d5['w_min_mc'],mvgandk_sw_n_d5['w_max_mc']-mvgandk_sw_n_d5['w_mc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d5['w_rqmc'], yerr=[mvgandk_sw_n_d5['w_rqmc']-mvgandk_sw_n_d5['w_min_rqmc'],mvgandk_sw_n_d5['w_max_rqmc']-mvgandk_sw_n_d5['w_rqmc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d10['w_rqmc'], yerr=[mvgandk_sw_n_d10['w_rqmc']-mvgandk_sw_n_d10['w_min_rqmc'],mvgandk_sw_n_d10['w_max_rqmc']-mvgandk_sw_n_d10['w_rqmc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d10['w_mc'], yerr=[mvgandk_sw_n_d10['w_mc']-mvgandk_sw_n_d10['w_min_mc'],mvgandk_sw_n_d10['w_max_mc']-mvgandk_sw_n_d10['w_mc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d25['w_rqmc'], yerr=[mvgandk_sw_n_d25['w_rqmc']-mvgandk_sw_n_d25['w_min_rqmc'],mvgandk_sw_n_d25['w_max_rqmc']-mvgandk_sw_n_d25['w_rqmc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d25['w_mc'], yerr=[mvgandk_sw_n_d25['w_mc']-mvgandk_sw_n_d25['w_min_mc'],mvgandk_sw_n_d25['w_max_mc']-mvgandk_sw_n_d25['w_mc']], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d50['w_rqmc'], yerr=[mvgandk_sw_n_d50['w_rqmc']-mvgandk_sw_n_d50['w_min_rqmc'],mvgandk_sw_n_d50['w_max_rqmc']-mvgandk_sw_n_d50['w_rqmc']], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.errorbar(n, mvgandk_sw_n_d50['w_mc'], yerr=[mvgandk_sw_n_d50['w_mc']-mvgandk_sw_n_d50['w_min_mc'],mvgandk_sw_n_d50['w_max_mc']-mvgandk_sw_n_d50['w_mc']], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.set_xscale('log', basex=2)
ax1.set_yscale('log', basey=10)
ax1.set_xlabel('n=m')
ax1.set_ylabel(r'$|SW_{c,p}(P^n,Q^m)|$')
ax1.set_title('varying n=m')
ax1.legend(loc= 'lower left',ncol=2,handlelength=1.5,labelspacing=0.3,handletextpad=0.3,columnspacing=1)

# SW(P^n,Q^m) against d
ax2.plot(d, mvgandk_sw_d['w_mc'], linewidth=2, color=cmap(0),label='MC')
ax2.plot(d, mvgandk_sw_d['w_rqmc'], linewidth=2, color=cmap(2),label='RQMC')
ax2.errorbar(d, mvgandk_sw_d['w_mc'], yerr=[mvgandk_sw_d['w_mc']-mvgandk_sw_d['w_min_mc'],mvgandk_sw_d['w_max_mc']-mvgandk_sw_d['w_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2.errorbar(d, mvgandk_sw_d['w_rqmc'], yerr=[mvgandk_sw_d['w_rqmc']-mvgandk_sw_d['w_min_rqmc'],mvgandk_sw_d['w_max_rqmc']-mvgandk_sw_d['w_rqmc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2.set_xlabel('d')
ax2.set_title('n=m='+r'$2^{13}$'+', varying d')
ax2.set_xticks(np.hstack((np.ones(1),np.arange(100,400,100)))) 
ax2.set_xticklabels(np.hstack((np.ones(1),np.arange(100,400,100))).astype(int))
ax2.legend(loc= 'lower right')

plt.subplots_adjust(wspace=0.05, hspace=0.05)

plt.savefig('mvgandk_slicedw_convergence.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %%
from sklearn import linear_model

# %%
lm1_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d5['w_mc'])).reshape(-1,1))
lm1_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d5['w_rqmc'])).reshape(-1,1))
lm2_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d10['w_mc'])).reshape(-1,1))
lm2_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d10['w_rqmc'])).reshape(-1,1))
lm3_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d25['w_mc'])).reshape(-1,1))
lm3_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d25['w_rqmc'])).reshape(-1,1))
lm4_mc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d50['w_mc'])).reshape(-1,1))
lm4_rqmc = linear_model.LinearRegression().fit(np.log(n).reshape(-1,1),np.log(np.sqrt(mvgandk_sw_n_d50['w_rqmc'])).reshape(-1,1))

# %%
print('\\begin{tabular}{ c | c | c } ')
print('& MC & RQMC \\\\')
print('\hline')
print('$d=5$ &', np.round(np.squeeze(lm1_mc.coef_),4),'&',np.round(np.squeeze(lm1_rqmc.coef_),4),'\\\\')
print('$d=10$ &', np.round(np.squeeze(lm2_mc.coef_),4),'&',np.round(np.squeeze(lm2_rqmc.coef_),4),'\\\\')
print('$d=25$ &', np.round(np.squeeze(lm3_mc.coef_),4),'&',np.round(np.squeeze(lm3_rqmc.coef_),4),'\\\\')
print('$d=50$ &', np.round(np.squeeze(lm4_mc.coef_),4),'&',np.round(np.squeeze(lm4_rqmc.coef_),4),'\\\\')
print('\end{tabular}')
# Out:
# \begin{tabular}{ c | c | c }
# & MC & RQMC \\
# \hline
# $d=5$ & -0.1174 & -0.1466 \\
# $d=10$ & -0.1178 & -0.1398 \\
# $d=25$ & -0.1196 & -0.1316 \\
# $d=50$ & -0.12 & -0.1286 \\
# \end{tabular}

# %% [markdown]
# Convergence of the Sinkhorn divergence for the multivariate g-and-k distribution:

# %%
n = [ 2**j for j in range(3,15) ]
d = [1,5,10,15,20,25,50,75,100,150,200,300]

# %%
SMALL_SIZE = 28
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(18,8),sharey='row')
cmap = plt.get_cmap("tab10")

# S(P^n,Q^m) against n
ax1.plot(n[:-1], mvgandk_sink_n_d1['sink_rqmc'], linewidth=2, color=cmap(0), label='d=1')
ax1.plot(n[:-1], mvgandk_sink_n_d1['sink_mc'],'--', linewidth=2, color=cmap(0))
ax1.plot(n[:-1], mvgandk_sink_n_d5['sink_rqmc'], linewidth=2, color=cmap(1), label='d=5')
ax1.plot(n[:-1], mvgandk_sink_n_d5['sink_mc'],'--', linewidth=2, color=cmap(1))
ax1.plot(n[:-1], mvgandk_sink_n_d10['sink_rqmc'][:-1], linewidth=2, color=cmap(2), label='d=10')
ax1.plot(n[:-1], mvgandk_sink_n_d10['sink_mc'][:-1],'--', linewidth=2, color=cmap(2))
ax1.plot(n[:-1], mvgandk_sink_n_d25['sink_rqmc'][:-1], linewidth=2, color=cmap(3), label='d=25')
ax1.plot(n[:-1], mvgandk_sink_n_d25['sink_mc'][:-1],'--', linewidth=2, color=cmap(3))
ax1.plot(n[:-1], mvgandk_sink_n_d50['sink_rqmc'][:-1], linewidth=2, color=cmap(4), label='d=50')
ax1.plot(n[:-1], mvgandk_sink_n_d50['sink_mc'][:-1],'--', linewidth=2, color=cmap(4))
ax1.errorbar(n[:-1], mvgandk_sink_n_d1['sink_mc'], yerr=[mvgandk_sink_n_d1['sink_mc']-mvgandk_sink_n_d1['sink_min_mc'],mvgandk_sink_n_d1['sink_max_mc']-mvgandk_sink_n_d1['sink_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d1['sink_rqmc'], yerr=[mvgandk_sink_n_d1['sink_rqmc']-mvgandk_sink_n_d1['sink_min_rqmc'],mvgandk_sink_n_d1['sink_max_rqmc']-mvgandk_sink_n_d1['sink_rqmc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d5['sink_mc'], yerr=[mvgandk_sink_n_d5['sink_mc']-mvgandk_sink_n_d5['sink_min_mc'],mvgandk_sink_n_d5['sink_max_mc']-mvgandk_sink_n_d5['sink_mc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d5['sink_rqmc'], yerr=[mvgandk_sink_n_d5['sink_rqmc']-mvgandk_sink_n_d5['sink_min_rqmc'],mvgandk_sink_n_d5['sink_max_rqmc']-mvgandk_sink_n_d5['sink_rqmc']], fmt='.', color=cmap(1), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d10['sink_rqmc'][:-1], yerr=[mvgandk_sink_n_d10['sink_rqmc'][:-1]-mvgandk_sink_n_d10['sink_min_rqmc'][:-1],mvgandk_sink_n_d10['sink_max_rqmc'][:-1]-mvgandk_sink_n_d10['sink_rqmc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d10['sink_mc'][:-1], yerr=[mvgandk_sink_n_d10['sink_mc'][:-1]-mvgandk_sink_n_d10['sink_min_mc'][:-1],mvgandk_sink_n_d10['sink_max_mc'][:-1]-mvgandk_sink_n_d10['sink_mc'][:-1]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d25['sink_rqmc'][:-1], yerr=[mvgandk_sink_n_d25['sink_rqmc'][:-1]-mvgandk_sink_n_d25['sink_min_rqmc'][:-1],mvgandk_sink_n_d25['sink_max_rqmc'][:-1]-mvgandk_sink_n_d25['sink_rqmc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d25['sink_mc'][:-1], yerr=[mvgandk_sink_n_d25['sink_mc'][:-1]-mvgandk_sink_n_d25['sink_min_mc'][:-1],mvgandk_sink_n_d25['sink_max_mc'][:-1]-mvgandk_sink_n_d25['sink_mc'][:-1]], fmt='.', color=cmap(3), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d50['sink_rqmc'][:-1], yerr=[mvgandk_sink_n_d50['sink_rqmc'][:-1]-mvgandk_sink_n_d50['sink_min_rqmc'][:-1],mvgandk_sink_n_d50['sink_max_rqmc'][:-1]-mvgandk_sink_n_d50['sink_rqmc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.errorbar(n[:-1], mvgandk_sink_n_d50['sink_mc'][:-1], yerr=[mvgandk_sink_n_d50['sink_mc'][:-1]-mvgandk_sink_n_d50['sink_min_mc'][:-1],mvgandk_sink_n_d50['sink_max_mc'][:-1]-mvgandk_sink_n_d50['sink_mc'][:-1]], fmt='.', color=cmap(4), capsize=10, elinewidth=1.5)
ax1.set_xscale('log', basex=2)
ax1.set_yscale('log', basey=10)
ax1.set_ylim(1e-8,500)
ax1.set_xlabel('n=m')
ax1.set_ylabel(r'$|S_{c,p,\lambda}(P^n,Q^m)|$')
ax1.set_title('varying n=m')
ax1.legend(loc= 'lower left',ncol=2,handlelength=1.5,labelspacing=0.3,handletextpad=0.3,columnspacing=1)

# S(P^n,Q^m) against d
ax2.plot(d, mvgandk_sink_d['sink_mc'], linewidth=2, color=cmap(0),label='MC')
ax2.plot(d, mvgandk_sink_d['sink_rqmc'], linewidth=2, color=cmap(2),label='RQMC')
ax2.errorbar(d, mvgandk_sink_d['sink_mc'], yerr=[mvgandk_sink_d['sink_mc']-mvgandk_sink_d['sink_min_mc'],mvgandk_sink_d['sink_max_mc']-mvgandk_sink_d['sink_mc']], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2.errorbar(d, mvgandk_sink_d['sink_rqmc'], yerr=[mvgandk_sink_d['sink_rqmc']-mvgandk_sink_d['sink_min_rqmc'],mvgandk_sink_d['sink_max_rqmc']-mvgandk_sink_d['sink_rqmc']], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2.set_xlabel('d')
ax2.set_title('n=m='+r'$2^{12}$'+', varying d')
ax2.set_xticks(np.hstack((np.ones(1),np.arange(100,400,100)))) 
ax2.set_xticklabels(np.hstack((np.ones(1),np.arange(100,400,100))).astype(int))
ax2.legend(loc= 'lower left',handlelength=1.5,labelspacing=0.3,handletextpad=0.3,columnspacing=1)

l = 7
ax2plus = fig.add_axes([0.69,0.2,0.2,0.3])
ax2plus.plot(d[:-l], mvgandk_sink_d['sink_mc'][:-l], linewidth=2, label='MC')
ax2plus.plot(d[:-l], mvgandk_sink_d['sink_rqmc'][:-l], linewidth=2, color=cmap(2), label='Halton')
ax2plus.errorbar(d[:-l], mvgandk_sink_d['sink_mc'][:-l], yerr=[mvgandk_sink_d['sink_mc'][:-l]-mvgandk_sink_d['sink_min_mc'][:-l],mvgandk_sink_d['sink_max_mc'][:-l]-mvgandk_sink_d['sink_mc'][:-l]], fmt='.', color=cmap(0), capsize=10, elinewidth=1.5)
ax2plus.errorbar(d[:-l], mvgandk_sink_d['sink_rqmc'][:-l], yerr=[mvgandk_sink_d['sink_rqmc'][:-l]-mvgandk_sink_d['sink_min_rqmc'][:-l],mvgandk_sink_d['sink_max_rqmc'][:-l]-mvgandk_sink_d['sink_rqmc'][:-l]], fmt='.', color=cmap(2), capsize=10, elinewidth=1.5)
ax2plus.set_yscale('log', basey=10)
ax2plus.set_xticks(d[:-l]) 
#ax2plus.set_xticks(np.hstack((np.ones(1),np.arange(5,15,5)))) 
#ax2plus.set_xticklabels(np.hstack((np.ones(1),np.arange(5,15,5))).astype(int))

plt.subplots_adjust(wspace=0.05, hspace=0.05)

plt.savefig('mvgandk_sinkhorn_convergence.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
from sklearn import linear_model

# %%
lm1_mc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d5['sink_mc'])).reshape(-1,1))
lm1_rqmc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d5['sink_rqmc'])).reshape(-1,1))
lm2_mc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d10['sink_mc'][:-1])).reshape(-1,1))
lm2_rqmc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d10['sink_rqmc'][:-1])).reshape(-1,1))
lm3_mc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d25['sink_mc'][:-1])).reshape(-1,1))
lm3_rqmc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d25['sink_rqmc'][:-1])).reshape(-1,1))
lm4_mc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d50['sink_mc'][:-1])).reshape(-1,1))
lm4_rqmc = linear_model.LinearRegression().fit(np.log(n[:-1]).reshape(-1,1),np.log(np.sqrt(mvgandk_sink_n_d50['sink_rqmc'][:-1])).reshape(-1,1))

# %%
print('\\begin{tabular}{ c | c | c } ')
print('& MC & RQMC \\\\')
print('\hline')
print('$d=5$ &', np.round(np.squeeze(lm1_mc.coef_),4),'&',np.round(np.squeeze(lm1_rqmc.coef_),4),'\\\\')
print('$d=10$ &', np.round(np.squeeze(lm2_mc.coef_),4),'&',np.round(np.squeeze(lm2_rqmc.coef_),4),'\\\\')
print('$d=25$ &', np.round(np.squeeze(lm3_mc.coef_),4),'&',np.round(np.squeeze(lm3_rqmc.coef_),4),'\\\\')
print('$d=50$ &', np.round(np.squeeze(lm4_mc.coef_),4),'&',np.round(np.squeeze(lm4_rqmc.coef_),4),'\\\\')
print('\end{tabular}')
# Out:
# \begin{tabular}{ c | c | c }
# & MC & RQMC \\
# \hline
# $d=5$ & -0.309 & -0.331 \\
# $d=10$ & -0.2749 & -0.2982 \\
# $d=25$ & -0.261 & -0.2631 \\
# $d=50$ & -0.2918 & -0.2957 \\
# \end{tabular}

# %% [markdown]
# Plot of the optimisation loss for the multivariate g-and-k distribution and $d=10$:

# %%
SMALL_SIZE = 32
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
plt.figure(figsize=(16,7))
cmap = plt.get_cmap("tab10")

plt.plot(np.abs(mvgandk_mmd2_optim_d10_mc['loss']), color=cmap(0),label='MC')
plt.plot(np.abs(mvgandk_mmd2_optim_d10_rqmc['loss']), color=cmap(2),label='RQMC')
plt.yscale('log', basey=10)
plt.ylabel(r'$|\widehat{MMD}^2_V(P^n,Q^m)|$')
plt.legend(loc='upper right')
plt.xlabel('Descent steps')

plt.savefig('gandk_mmd2_loss.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %% [markdown]
# Plot of the l2-norm of the estimates for the multivariate g-and-k distribution and $d=10$:

# %%
theta = np.array([3,1,1,-np.log(2),0.1])
max_it = mvgandk_mmd2_optim_d10_mc['theta'].shape[0]-1

# %%
dist_mc = distance.cdist(mvgandk_mmd2_optim_d10_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc = distance.cdist(mvgandk_mmd2_optim_d10_rqmc['theta'],np.expand_dims(theta,0),'euclidean')

plt.figure(figsize=(16,7))
cmap = plt.get_cmap("tab10")

plt.plot(dist_mc, color=cmap(0), label='MC')
plt.plot(dist_rqmc, color=cmap(2), label='RQMC')
plt.yscale('log', basey=10)
plt.ylabel(r'$||\hat{\theta}-\theta^*||_2$')
plt.xlabel('Descent steps')
plt.title(r'$\theta^*=($'+str(theta[0].astype(int))+', '+str(theta[1].astype(int))+', '+str(theta[2].astype(int))+r'$,-\log(2), $'+str(theta[4])+')')
plt.legend(loc='upper right')

plt.savefig('gandk_mmd2_estimates_l2norm.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %% [markdown]
# Plot of the absolute error of the individual estimates for the multivariate g-and-k distribution and $d=10$:

# %%
SMALL_SIZE = 32
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(1,5,figsize=(38,8),sharey='row')
cmap = plt.get_cmap("tab10")

ax1.plot(range(max_it+1),np.abs(theta[0]-mvgandk_mmd2_optim_d10_mc['theta'][:,0]), color=cmap(0), label='MC')
ax1.plot(range(max_it+1),np.abs(theta[0]-mvgandk_mmd2_optim_d10_rqmc['theta'][:,0]), color=cmap(2), label='RQMC')
ax1.set_yscale('log', basey=10)
ax1.set_xlabel('Descent steps')
ax1.set_ylabel(r'$|\theta_i^*-\hat{\theta}_i|$')
ax1.set_title(r'$\theta^*_{1}=$'+str(theta[0].astype(int)))

ax2.plot(range(max_it+1),np.abs(theta[1]-mvgandk_mmd2_optim_d10_mc['theta'][:,1]), color=cmap(0), label='MC')
ax2.plot(range(max_it+1),np.abs(theta[1]-mvgandk_mmd2_optim_d10_rqmc['theta'][:,1]), color=cmap(2), label='RQMC')
ax2.set_yscale('log', basey=10)
ax2.set_xlabel('Descent steps')
ax2.set_title(r'$\theta^*_{2}=$'+str(theta[1].astype(int)))

ax3.plot(range(max_it+1),np.abs(theta[2]-mvgandk_mmd2_optim_d10_mc['theta'][:,2]), color=cmap(0), label='MC')
ax3.plot(range(max_it+1),np.abs(theta[2]-mvgandk_mmd2_optim_d10_rqmc['theta'][:,2]), color=cmap(2), label='RQMC')
ax3.set_yscale('log', basey=10)
ax3.set_xlabel('Descent steps')
ax3.set_title(r'$\theta^*_{3}=$'+str(theta[2].astype(int)))

ax4.plot(range(max_it+1),np.abs(theta[3]-mvgandk_mmd2_optim_d10_rqmc['theta'][:,3]), color=cmap(0), label='MC')
ax4.plot(range(max_it+1),np.abs(theta[3]-mvgandk_mmd2_optim_d10_rqmc['theta'][:,3]), color=cmap(2), label='RQMC')
ax4.set_yscale('log', basey=10)
ax4.set_xlabel('Descent steps')
#ax4.set_title(r'$\theta^*_{4}=$'+str(round(theta[3],4)))
ax4.set_title(r'$\theta^*_{4}=-\log(2)$')

ax5.plot(range(max_it+1),np.abs(theta[4]-mvgandk_mmd2_optim_d10_rqmc['theta'][:,4]), color=cmap(0), label='MC')
ax5.plot(range(max_it+1),np.abs(theta[4]-mvgandk_mmd2_optim_d10_rqmc['theta'][:,4]), color=cmap(2), label='RQMC')
ax5.set_yscale('log', basey=10)
ax5.set_xlabel('Descent steps')
#ax5.set_title(r'$\theta^*_{4}=$'+str(round(theta[3],4)))
ax5.set_title(r'$\theta^*_{5}=0.1$')
ax5.legend(loc='lower right')

plt.subplots_adjust(wspace=0.05, hspace=0.05)

plt.savefig('gandk_mmd2_estimates.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %% [markdown]
# Plot of the l2-norm of the estimates for the multivariate g-and-k distribution and different $d$:

# %%
d = [2,5,10,15,20,25]

# %%
#dist_mc_d1 = distance.cdist(gank_mmd2_optim_kgaussian['theta_mc'],np.expand_dims(theta[:-1],0),'euclidean')
#dist_rqmc_d1 = distance.cdist(gank_mmd2_optim_kgaussian['theta_rqmc'],np.expand_dims(theta[:-1],0),'euclidean')
dist_mc_d1 = distance.cdist(mvgandk_mmd2_optim_d1_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc_d1 = distance.cdist(mvgandk_mmd2_optim_d1_rqmc['theta'],np.expand_dims(theta,0),'euclidean')
dist_mc_d2 = distance.cdist(mvgandk_mmd2_optim_d2_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc_d2 = distance.cdist(mvgandk_mmd2_optim_d2_rqmc['theta'],np.expand_dims(theta,0),'euclidean')
dist_mc_d5 = distance.cdist(mvgandk_mmd2_optim_d5_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc_d5 = distance.cdist(mvgandk_mmd2_optim_d5_rqmc['theta'],np.expand_dims(theta,0),'euclidean')
dist_mc_d10 = distance.cdist(mvgandk_mmd2_optim_d10_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc_d10 = distance.cdist(mvgandk_mmd2_optim_d10_rqmc['theta'],np.expand_dims(theta,0),'euclidean')
dist_mc_d15 = distance.cdist(mvgandk_mmd2_optim_d15_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc_d15 = distance.cdist(mvgandk_mmd2_optim_d15_rqmc['theta'],np.expand_dims(theta,0),'euclidean')
dist_mc_d20 = distance.cdist(mvgandk_mmd2_optim_d20_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc_d20 = distance.cdist(mvgandk_mmd2_optim_d20_rqmc['theta'],np.expand_dims(theta,0),'euclidean')
dist_mc_d25 = distance.cdist(mvgandk_mmd2_optim_d25_mc['theta'],np.expand_dims(theta,0),'euclidean')
dist_rqmc_d25 = distance.cdist(mvgandk_mmd2_optim_d25_rqmc['theta'],np.expand_dims(theta,0),'euclidean')

# %%
dist_mc = [dist_mc_d2[-1],dist_mc_d5[-1],dist_mc_d10[-1],dist_mc_d15[-1],dist_mc_d20[-1],dist_mc_d25[-1]]
dist_rqmc = [dist_rqmc_d2[-1],dist_rqmc_d5[-1],dist_rqmc_d10[-1],dist_rqmc_d15[-1],dist_rqmc_d20[-1],dist_rqmc_d25[-1]]

# %%
plt.figure(figsize=(16,7))
cmap = plt.get_cmap("tab10")

plt.plot(d,dist_mc, color=cmap(0), label='MC')
plt.plot(d,dist_rqmc, color=cmap(2), label='RQMC')
plt.yscale('log', basey=10)
plt.ylabel(r'$||\hat{\theta}-\theta^*||_2$')
plt.xlabel('d')
#plt.title(r'$\theta^*=($'+str(theta[0].astype(int))+', '+str(theta[1].astype(int))+', '+str(theta[2].astype(int))+r'$,-\log(2))$')
plt.xticks(d)
plt.legend()

plt.savefig('gandk_mmd2_estimates_l2norm.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %%
def adjust_lightness(color, amount=0.5):
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], max(0, min(1, amount * c[1])), c[2])

# %%
plt.figure(figsize=(22,10))
cmap = plt.get_cmap("tab10")

plt.plot(dist_mc_d5, color=adjust_lightness(cmap(0),1.5))
plt.plot(dist_rqmc_d5, color=cmap(0), label='d=5')
plt.plot(dist_mc_d10, color=adjust_lightness(cmap(1),1.5))
plt.plot(dist_rqmc_d10, color=cmap(1), label='d=10')
plt.plot(dist_mc_d15, color=adjust_lightness(cmap(2),1.5))
plt.plot(dist_rqmc_d15, color=cmap(2), label='d=15')
plt.plot(dist_mc_d20, color=adjust_lightness(cmap(3),1.5))
plt.plot(dist_rqmc_d20, color=cmap(3), label='d=20')
plt.plot(dist_mc_d25, color=adjust_lightness(cmap(4),1.5))
plt.plot(dist_rqmc_d25, color=cmap(4), label='d=25')
plt.yscale('log', basey=10)
#plt.xscale('log', basex=10)
plt.ylabel(r'$||\hat{\theta}-\theta^*||_2$')
plt.xlabel('Descent steps')
plt.title(r'$\theta^*=($'+str(theta[0].astype(int))+', '+str(theta[1].astype(int))+', '+str(theta[2].astype(int))+r'$,-\log(2), $'+str(theta[4])+')')
plt.legend(loc='lower left',ncol=2,handlelength=1.5,labelspacing=0.3,handletextpad=0.3,columnspacing=1)

plt.savefig('mvgandk_mmd2_estimates_l2norm.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()

# %%
SMALL_SIZE = 26
MEDIUM_SIZE = 32
BIGGER_SIZE = 32

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title

# %%
fig,axes = plt.subplots(2,3,figsize=(32,16),sharey=True)
cmap = plt.get_cmap("tab10")

axes[1][2].set_visible(False)

axes[0][0].plot(mvgandk_mmd2_optim_d5_mc['loss'], color=adjust_lightness(cmap(0),1.5), label='MC')
axes[0][0].plot(mvgandk_mmd2_optim_d5_rqmc['loss'], color=cmap(0), label='RQMC')
axes[0][0].set_ylabel(r'$|\widehat{MMD}^2_V(P^n,Q^m)|$')
axes[0][0].set_yscale('log', basey=10)
axes[0][0].set_xlabel('Descent steps')
axes[0][0].set_title('d=5')
axes[0][0].legend()

axes[0][1].plot(mvgandk_mmd2_optim_d10_mc['loss'], color=adjust_lightness(cmap(1),1.5), label='MC')
axes[0][1].plot(mvgandk_mmd2_optim_d10_rqmc['loss'], color=cmap(1), label='RQMC')
axes[0][1].set_yscale('log', basey=10)
axes[0][1].set_xlabel('Descent steps')
axes[0][1].set_title('d=10')
axes[0][1].legend()

axes[0][2].plot(mvgandk_mmd2_optim_d15_mc['loss'], color=adjust_lightness(cmap(2),1.5), label='MC')
axes[0][2].plot(mvgandk_mmd2_optim_d15_rqmc['loss'], color=cmap(2), label='RQMC')
axes[0][2].set_yscale('log', basey=10)
axes[0][2].set_xlabel('Descent steps')
axes[0][2].set_title('d=15')
axes[0][2].legend()

axes[1][0].plot(mvgandk_mmd2_optim_d20_mc['loss'], color=adjust_lightness(cmap(3),1.5), label='MC')
axes[1][0].plot(mvgandk_mmd2_optim_d20_rqmc['loss'], color=cmap(3), label='RQMC')
axes[1][0].set_ylabel(r'$|\widehat{MMD}^2_V(P^n,Q^m)|$')
axes[1][0].set_yscale('log', basey=10)
axes[1][0].set_xlabel('Descent steps')
axes[1][0].set_title('d=20')
axes[1][0].legend()

axes[1][1].plot(mvgandk_mmd2_optim_d25_mc['loss'], color=adjust_lightness(cmap(4),1.5), label='MC')
axes[1][1].plot(mvgandk_mmd2_optim_d25_rqmc['loss'], color=cmap(4),  label='RQMC')
axes[1][1].set_yscale('log', basey=10)
axes[1][1].set_xlabel('Descent steps')
axes[1][1].set_title('d=25')
axes[1][1].legend()

#plt.subplots_adjust(wspace=0.05, hspace=0.5)

#axes[1][0].set_position([0.24,0.125,0.228,0.343])
#axes[1][1].set_position([0.55,0.125,0.228,0.343])
axes[1][0].set_position([0.24,0.09,0.228,0.343])
axes[1][1].set_position([0.55,0.09,0.228,0.343])

plt.savefig('mvgandk_mmd2_loss.png',bbox_inches = 'tight', pad_inches = .1)
plt.show()
