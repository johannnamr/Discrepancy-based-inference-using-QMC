# %% [markdown]
# <a href="https://colab.research.google.com/github/johannnamr/Discrepancy-based-inference-using-QMC/blob/main/Inference/Bv-beta-distribution/bibeta_conv_W.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bivariate Beta Model
#
# Notebook for the convergence of the Wasserstein distance

# %% [markdown]
# ### Mount Drive

# %%
# mount my drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# The following path has to be adjusted if necessary:

# %%
# %run "/content/drive/My Drive/Colab Notebooks/Utils.ipynb"
# %run "/content/drive/My Drive/Colab Notebooks/Plot_fcts.ipynb"

# %% [markdown]
# Define saving path (adjust if necessary):

# %%
path = '/content/drive/My Drive/Colab Notebooks/Paper/Inference/'

# %% [markdown]
# ### Imports

# %%
import numpy as np

# %% [markdown]
# ### Wasserstein distance convergence

# %% [markdown]
# Calculate Wasserstein distance for fixed $d=2$ and varying $n$:

# %%
np.random.seed(11)

# %% [markdown]
# Set parameters:

# %%
n = [ 2**j for j in range(3,15) ]       # number of simulated samples - powers of 2
m = 2**15                               # number of true samples
num = 25                                # numbers of repetitions for MC and RQMC
theta = (1.5,1.5,1.5,1.5,1.5)                     # true theta
d = 2                                    # data dimensions
cost = 'euclidean'                      # distance used for ground cost ('euclidean', 'sqeuclidean',‘minkowski’ or ‘cityblock’)

# %% [markdown]
# Define QMC sequence:

# %%
i_theta,_ = divmod(theta,np.ones(5)) 
i_theta.astype(int)
qmc = qmcpy.Halton(np.sum(i_theta.astype(int)),seed=7)

# %% [markdown]
# Calculate Wasserstein distance for varying $n$:

# %%
w_mc,w_qmc,w_rqmc,w_min_mc,w_max_mc,w_min_rqmc,w_max_rqmc = W_conv('bibeta',n,num,d,theta,cost=cost)
# Out:
# sample size:  8
# sample size:  16
# sample size:  32
# sample size:  64
# sample size:  128
# sample size:  256
# sample size:  512
# sample size:  1024
# sample size:  2048
# sample size:  4096
# /usr/local/lib/python3.7/dist-packages/ot/lp/__init__.py:421
# ...
# sample size:  8192
# sample size:  16384

# %% [markdown]
# Plot the Wasserstein distance against $n$:

# %%
plot_W_conv(2,(16,8),w_mc,w_qmc,w_rqmc,'MC','QMC','RQMC',w_min_mc,w_max_mc,w_min_rqmc,w_max_rqmc)

# %%
#np.savez(path+"bibeta_w_n_%s_int.npz" %(cost), w_mc=w_mc,w_min_mc=w_min_mc,w_max_mc=w_max_mc,w_rqmc=w_rqmc,w_min_rqmc=w_min_rqmc,w_max_rqmc=w_max_rqmc,w_qmc=w_qmc)
np.savez(path+"bibeta_w_n_%s_noint.npz" %(cost), w_mc=w_mc,w_min_mc=w_min_mc,w_max_mc=w_max_mc,w_rqmc=w_rqmc,w_min_rqmc=w_min_rqmc,w_max_rqmc=w_max_rqmc,w_qmc=w_qmc)
